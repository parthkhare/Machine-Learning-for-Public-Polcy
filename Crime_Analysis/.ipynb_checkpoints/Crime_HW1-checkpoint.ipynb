# %% [markdown]
# # Diagnostic_Crime

# %%
import requests
import pandas as pd
import calendar
import json
import folium
import seaborn as sns
import mapclassify
import datetime
import matplotlib.pyplot as plt
import geopandas as gpd
import shapely
import seaborn as sns
from shapely.geometry import Point
import censusgeocode as cg
import warnings
warnings.filterwarnings('ignore')

sns.set(style="ticks", color_codes=True)
# %matplotlib inline

# %%
def get_data(query_json):
    '''
    Generates a DataFrame of crime data using API

    Input: (Request Object) Request made to fetch data using API

    Output: (DataFrame) required Chicago crime data
    '''

    dicto = {}
    count = 0
    for val in query_json.json():
        dicto[count] = val
        count += 1
    df = pd.DataFrame.from_dict(dicto, orient='index')

    return df

def get_request(url_crime):
    '''
    Open a connection to the specified URL and if successful
    read the data.

    Inputs:
        url: must be an absolute URL

    Outputs:
        request object or None

    Examples:
        get_request("http://www.cs.uchicago.edu")
    '''

    try:
        req = requests.get(url_crime)
        if req.status_code == 404 or req.status_code == 403:
            req = None
    except Exception:
        # fail on any kind of error
        req = None

    return req

# %% [markdown]
# # Question 1

# %%
# Get Crime Data from API for 2017 and 2018
url_crime = "https://data.cityofchicago.org/resource/6zsd-86xi.json?$limit=550000&$where\
=date between '2017-01-01T00:00:00' and '2018-12-31T00:00:00'"
# Customised Functions for extraction 
crime_json = get_request(url_crime)
df = get_data(crime_json)
# Drop rows with missing values
df.dropna(inplace=True) # 1% records without location removed

# %%
# Check Import
print(df.shape)
print(df.columns)
print(df['primary_type'].value_counts().head())
df['block'].value_counts().head()
print(df['block'].nunique())
print(df['beat'].nunique())
print(df['community_area'].nunique())
print(df['district'].nunique())
print(df['ward'].nunique())
print(df['primary_type'].nunique())
df.head()
# Out:
# (526469, 22)
# Index(['arrest', 'beat', 'block', 'case_number', 'community_area', 'date',
#        'description', 'district', 'domestic', 'fbi_code', 'id', 'iucr',
#        'latitude', 'location', 'location_description', 'longitude',
#        'primary_type', 'updated_on', 'ward', 'x_coordinate', 'y_coordinate',
#        'year'],
#       dtype='object')
# THEFT                 127455
# BATTERY                98751
# CRIMINAL DAMAGE        56562
# ASSAULT                39551
# DECEPTIVE PRACTICE     34166
# Name: primary_type, dtype: int64
# 30634
# 274
# 77
# 23
# 50
# 32
#    arrest  beat                    block case_number community_area  \
# 0    True  1034  026XX S CALIFORNIA BLVD    JA529032             30
# 1    True  1221  007XX N SACRAMENTO BLVD    JA545986             23
# 5    True  0215          003XX E 47TH ST    JA522842             38
# 7   False  0524      117XX S SANGAMON ST    JB140548             53
# 8   False  2433    011XX W GRANVILLE AVE    JB108189             77
#
#                       date                            description district  \
# 0  2017-11-28T21:43:00.000  VIOLENT OFFENDER: ANNUAL REGISTRATION      010
# 1  2017-12-11T19:15:00.000                         ARMED: HANDGUN      012
# 5  2017-11-23T15:14:00.000                    AGGRAVATED: HANDGUN      002
# 7  2018-02-04T01:36:00.000                    FIRST DEGREE MURDER      005
# 8  2018-01-08T06:50:00.000                             AUTOMOBILE      024
#
#    domestic fbi_code  ...      latitude  \
# 0     False       26  ...  41.843778126
# 1     False       03  ...  41.894475919
# 5     False      04A  ...  41.809342727
# 7     False      01A  ...   41.68073915
# 8     False       07  ...   41.99456734
#
#                                             location     location_description  \
# 0  {'type': 'Point', 'coordinates': [-87.69463767...  JAIL / LOCK-UP FACILITY
# 1  {'type': 'Point', 'coordinates': [-87.70216915...                 SIDEWALK
# 5  {'type': 'Point', 'coordinates': [-87.61909899...         DEPARTMENT STORE
# 7  {'type': 'Point', 'coordinates': [-87.64566114...                   STREET
# 8  {'type': 'Point', 'coordinates': [-87.65901631...                   STREET
#
#        longitude         primary_type               updated_on ward  \
# 0  -87.694637678        OTHER OFFENSE  2018-02-11T15:54:58.000   12
# 1  -87.702169158              ROBBERY  2018-02-11T15:54:58.000   27
# 5  -87.619098999              ASSAULT  2018-06-21T15:59:22.000    3
# 7  -87.645661144             HOMICIDE  2019-03-18T16:08:09.000   34
# 8  -87.659016317  MOTOR VEHICLE THEFT  2018-05-04T15:51:04.000   48
#
#   x_coordinate y_coordinate  year
# 0      1158280      1886310  2017
# 1      1156092      1904769  2017
# 5      1178967      1873924  2017
# 7      1172100      1827003  2018
# 8      1167554      1941332  2018
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Add Neighbourhood to Crime Data using Spatial Join

# %%
# Import Neighbourhood Shapefile
nbh_shapefile_path = "/Users/parthkhare/Parth_Repos/Machine-Learning-for-Public-Polcy/Crime_Analysis/Shape/Neighborhoods_98/Neighborhoods_98.shp"
nbh = gpd.read_file(nbh_shapefile_path)
nbh = nbh.to_crs({'init': 'epsg:4326'}) # Set projection

# combine lat and lon column to a shapely Point() object
df['geometry'] = df.apply(lambda x: Point((float(x.longitude), float(x.latitude))), axis=1)
df_point = gpd.GeoDataFrame(df, geometry='geometry')
df_point.crs= "+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs"

# Crime Data for 2017 and 2018 with NBH
crime = gpd.sjoin(df_point, nbh, how="left", op = 'intersects')

# %% [markdown]
# ### Descriptive Statistics

# %%
# Descriptive Statistics: Crime Type
ax = crime['primary_type'].value_counts().sort_values(ascending =  False).plot(kind='bar',
                                                            width=0.9,
                                                            color='g',
                                                            alpha=0.5,
                                                            linewidth=0)
ax.set_xlabel('Crime Categories')
ax.set_ylabel('Reported Incidents')
plt.show()

# %%
# Date transformation
crime['date'] =  pd.to_datetime(crime['date'])
# Create a Year Month Variable
crime['Mnth_yr'] = crime['date'].apply(lambda x: x.strftime('%B-%Y')) 

# Top Crime Categories
top_cat = ['THEFT','BATTERY','CRIMINAL DAMAGE','ASSAULT','DECEPTIVE PRACTICE']
crime_top = crime[crime.primary_type.isin(top_cat)]

# Aggregate Crime by Year Month
crm_myt = crime_top.groupby(['Mnth_yr','primary_type'])['case_number'].agg('count').reset_index()
crm_myt['Mnth_yr'] = pd.to_datetime(crm_myt['Mnth_yr'])

fig, ax = plt.subplots(figsize = (12,6))    
sns.catplot(x="Mnth_yr", y="case_number", hue="primary_type", kind="point", data=crm_myt, ax=ax)
x_dates = crm_myt['Mnth_yr'].dt.strftime('%Y-%m-%d').sort_values().unique()
ax.set_xticklabels(labels=x_dates, rotation=45, ha='right')
ax.set_ylabel('Reported Incidents')
ax.set_xlabel('Months')
ax.set_title('Major Crime over Time')
plt.close(2)

# %%
# Aggregate Crime by Year Month
crm_nbh = crime.groupby(['PRI_NEIGH','Mnth_yr','primary_type'])['case_number'].agg('count').reset_index()
crm_nbh.head()

# join the geodataframe with the cleaned up csv dataframe
merged = nbh.set_index('PRI_NEIGH').join(crm_nbh.set_index('PRI_NEIGH'))
variable = 'case_number'
vmin, vmax = 200, 420 # set the range for the choropleth

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 6))
# create map
merged.plot(variable, cmap='Reds', linewidth=0.8, ax=ax)
ax.set_title('Crime by Neighbourhoods', fontdict={'fontsize': '20', 'fontweight' : '3'})
# Out:
# Text(0.5,1,'Crime by Neighbourhoods')

# %%
# Subset top categories
top_cat = ['THEFT','BATTERY','CRIMINAL DAMAGE','ASSAULT','DECEPTIVE PRACTICE']
crime_nbh_top = crm_nbh[crm_nbh.primary_type.isin(top_cat)]

g = sns.catplot(x="PRI_NEIGH", y="case_number", col = 'primary_type', jitter = False,data=crime_nbh_top)
g.set_xticklabels(rotation=50,fontsize=5)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Crime Types by Neighbourhoods')
# Out:
# Text(0.5,0.98,'Crime Types by Neighbourhoods')

# %% [markdown]
# # Question 2

# %%
# Extract Social Statistics Data From American Community Survey
family_income = 'B19101_001E,'
median_income='B19013_001E,'
total_population='B01003_001E,'
white='B02001_002E,'
educational_attainment='B15003_001E,'
gini='B17022_001E,' # ratio of income to poverty

variables=median_income+family_income+total_population+white+educational_attainment+gini+'NAME'



key = '6672193bb01252a3977177729df914e5a8f7f0e5'
url_acs = 'https://api.census.gov/data/2017/acs/acs5?get='+variables+'&for=tract:*&in=state:17%40county:031&key='+key


# url_acs = "https://api.census.gov/data/2017/acs/acs5?get=B01003_001E,B02001_002E,B19101_001E,B15003_001E,NAME&for=block%20group:*&in=state:17%20county:031&key=6672193bb01252a3977177729df914e5a8f7f0e5"



# Customised Functions for extraction 
acs_json = get_request(url_acs)
acs_df = get_data(acs_json)
acs_df.columns = acs_df.iloc[0]
acs_df.drop(acs_df.index[:1], inplace=True)
acs_df.rename(columns={'B01003_001E': 'Tot_Pop', 'B02001_002E': 'White_Race', 'B19101_001E': 'Family_Inc',
                       'B19013_001E': 'Med_Inc', 'B15003_001E': 'Educ_Atn', 'B17022_001E': 'Gini'}, inplace=True)
# Change Datatpye to Integer
acs_df[['Tot_Pop', 'White_Race','Family_Inc','Med_Inc','Educ_Atn','Gini']] = acs_df[['Tot_Pop',\
                   'White_Race','Family_Inc','Med_Inc','Educ_Atn','Gini']].astype(int)
acs_df['Other_Race'] = acs_df['Tot_Pop'].values-acs_df['White_Race'].values
acs_df.head()
# Out:
# 0 Med_Inc  Family_Inc  Tot_Pop  White_Race Educ_25Attain B17022_001E  \
# 1   84863        1538     5541        5032          4007        1538
# 2   57045         291     1600        1094          1132         291
# 3   44063        1223     6464        2842          3551        1223
# 4   24972         504     2307        1255          1324         504
# 5   35016         668     3298        2012          1886         668
#
# 0                                      NAME state county   tract  Other_Race
# 1  Census Tract 5610, Cook County, Illinois    17    031  561000         509
# 2  Census Tract 6401, Cook County, Illinois    17    031  640100         506
# 3  Census Tract 6305, Cook County, Illinois    17    031  630500        3622
# 4  Census Tract 6111, Cook County, Illinois    17    031  611100        1052
# 5  Census Tract 6114, Cook County, Illinois    17    031  611400        1286

# %%
# Import Tract Shapefile
trk_shapefile_path = "/Users/parthkhare/Desktop/MSCAPP Quarters/Quarter 2/CS Q2/Project/Data/Chicago Admin Boundaries/Census Tracts_801/CTracts_801.shp"
trk = gpd.read_file(trk_shapefile_path)
trk = trk.to_crs({'init': 'epsg:4326'}) # Set projection
# Rename merge id name
crime = crime.rename(columns={'index_right': 'mergeid_nbh'})
# Spatial Join integrated crime (with NBH) Block Shapefile to link tracts
crime_trk = gpd.sjoin(crime, trk, how="left", op = 'intersects')

# %%
# Aggregate Acs by Tracts (remove duplicated by block groups)
acs_trk = acs_df.groupby(['tract'])['Tot_Pop','Family_Inc','Other_Race'].agg('sum').reset_index()
# Merge ACS and Crime
acs_crm = pd.merge(left=crime_trk, right=acs_trk, left_on='tractce10', right_on='tract', how='inner')
acs_crm.shape

# %%
# Out:
# (526987, 43)

# %%
525237,
526987,

526987-525237

B08135_001E: aggregate time to work in minutes
B14007_001E: SCHOOL ENROLLMENT BY DETAILED LEVEL OF SCHOOL FOR THE POPULATION 3 YEARS AND OVER
    B14007_019E: SCHOOL ENROLLMENT BY DETAILED LEVEL OF SCHOOL FOR THE POPULATION 3 YEARS AND OVER
        B15003_001E: EDUCATIONAL ATTAINMENT FOR THE POPULATION 25 YEARS AND OVER
            B15003_002E:No schooling completed
                B17022_001E: RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY PRESENCE OF RELATED CHILDREN UNDER 18 YEARS BY AGE OF RELATED CHILDREN
# Out:
# Index(['arrest', 'beat', 'block', 'case_number', 'community_area', 'date',
#        'description', 'district', 'domestic', 'fbi_code', 'id', 'iucr',
#        'latitude', 'location', 'location_description', 'longitude',
#        'primary_type', 'updated_on', 'ward', 'x_coordinate', 'y_coordinate',
#        'year', 'geometry', 'mergeid_nbh', 'PRI_NEIGH', 'SEC_NEIGH',
#        'SHAPE_AREA', 'SHAPE_LEN', 'Mnth_yr'],
#       dtype='object')

# %%
crime_trk.head()
# Out:
#    arrest  beat                    block case_number community_area  \
# 0    True  1034  026XX S CALIFORNIA BLVD    JA529032             30
# 1    True  1221  007XX N SACRAMENTO BLVD    JA545986             23
# 5    True  0215          003XX E 47TH ST    JA522842             38
# 7   False  0524      117XX S SANGAMON ST    JB140548             53
# 8   False  2234         011XX W 111TH ST    JB107989             75
#
#                  date                            description district  \
# 0 2017-11-28 21:43:00  VIOLENT OFFENDER: ANNUAL REGISTRATION      010
# 1 2017-12-11 19:15:00                         ARMED: HANDGUN      012
# 5 2017-11-23 15:14:00                    AGGRAVATED: HANDGUN      002
# 7 2018-02-04 01:36:00                    FIRST DEGREE MURDER      005
# 8 2018-01-07 21:01:00                DOMESTIC BATTERY SIMPLE      022
#
#    domestic fbi_code  ... index_right commarea commarea_n countyfp10  \
# 0     False       26  ...       127.0       30       30.0        031
# 1     False       03  ...       186.0       23       23.0        031
# 5     False      04A  ...       455.0       38       38.0        031
# 7     False      01A  ...       653.0       53       53.0        031
# 8      True      08B  ...       326.0       75       75.0        031
#
#        geoid10 name10         namelsad10 notes statefp10 tractce10
# 0  17031843500   8435  Census Tract 8435  None        17    843500
# 1  17031836700   8367  Census Tract 8367  None        17    836700
# 5  17031381400   3814  Census Tract 3814  None        17    381400
# 7  17031530300   5303  Census Tract 5303  None        17    530300
# 8  17031750100   7501  Census Tract 7501  None        17    750100
#
# [5 rows x 39 columns]

# %%
print(acs_df.columns)
crime_trk.columns
# Out:
# Index(['Tot_Pop', 'White_Race', 'Family_Inc', 'Gini', 'NAME', 'state',
#        'county', 'tract', 'block group', 'Other_Race'],
#       dtype='object', name=0)
# Index(['arrest', 'beat', 'block', 'case_number', 'community_area', 'date',
#        'description', 'district', 'domestic', 'fbi_code', 'id', 'iucr',
#        'latitude', 'location', 'location_description', 'longitude',
#        'primary_type', 'updated_on', 'ward', 'x_coordinate', 'y_coordinate',
#        'year', 'geometry', 'mergeid_nbh', 'PRI_NEIGH', 'SEC_NEIGH',
#        'SHAPE_AREA', 'SHAPE_LEN', 'Mnth_yr', 'index_right', 'commarea',
#        'commarea_n', 'countyfp10', 'geoid10', 'name10', 'namelsad10', 'notes',
#        'statefp10', 'tractce10'],
#       dtype='object')

# %%
acs_df.head()
# Out:
# 0  Tot_Pop  White_Race Family_Inc  Gini  \
# 1      600          11        109  None
# 2     1546          78        272  None
# 3     1341         977        313  None
# 4     1356        1023        288  None
# 5      616         616        173  None
#
# 0                                               NAME state county   tract  \
# 1  Block Group 1, Census Tract 2519, Cook County,...    17    031  251900
# 2  Block Group 2, Census Tract 2519, Cook County,...    17    031  251900
# 3  Block Group 1, Census Tract 8211.01, Cook Coun...    17    031  821101
# 4  Block Group 3, Census Tract 8211.01, Cook Coun...    17    031  821101
# 5  Block Group 2, Census Tract 8211.01, Cook Coun...    17    031  821101
#
# 0 block group  Other_Race
# 1           1         589
# 2           2        1468
# 3           1         364
# 4           3         333
# 5           2           0

# %%
acs_df.dtypes
acs_df['Family_Inc'] = acs_df['Family_Inc'].astype(int)

# %%
acs_trk = acs_df.groupby(['tract'])['Tot_Pop','Family_Inc','Other_Race'].agg('sum').reset_index()

# %%
acs_trk.head()
# Out:
# 0   tract  Tot_Pop  Family_Inc  Other_Race
# 0  010100     4444         883        2435
# 1  010201     7197        1587        3563
# 2  010202     2487         417        1256
# 3  010300     6413        1051        2554
# 4  010400     5411         720        1650

# %%
type(crime)
crime_df = pd.DataFrame(crime)
type(crime_df)
# Out:
# pandas.core.frame.DataFrame

# %%
crm_blkgp = pd.merge(left=crime_trk, right=acs_trk, left_on='tractce10', right_on='tract', how='outer')

# %%
crm_blkgp.head()
# Out:
#   arrest  beat                    block case_number community_area  \
# 0   True  1034  026XX S CALIFORNIA BLVD    JA529032             30
# 1  False  1032       026XX S KEDZIE AVE    JB116615             30
# 2  False  1033   026XX S CALIFORNIA AVE    JA107780             30
# 3  False  1033   026XX S CALIFORNIA AVE    JA110662             30
# 4  False  1033          031XX W 27TH ST    JA118537             30
#
#                  date                            description district  \
# 0 2017-11-28 21:43:00  VIOLENT OFFENDER: ANNUAL REGISTRATION      010
# 1 2018-01-14 18:00:00                              OVER $500      010
# 2 2017-01-07 21:15:00         SEX OFFENDER: FAIL TO REGISTER      010
# 3 2017-01-10 13:00:00                              OVER $500      010
# 4 2017-01-15 16:00:00                             TO VEHICLE      010
#
#   domestic fbi_code  ...      geoid10 name10         namelsad10 notes  \
# 0    False       26  ...  17031843500   8435  Census Tract 8435  None
# 1    False       06  ...  17031843500   8435  Census Tract 8435  None
# 2    False       26  ...  17031843500   8435  Census Tract 8435  None
# 3    False       06  ...  17031843500   8435  Census Tract 8435  None
# 4    False       14  ...  17031843500   8435  Census Tract 8435  None
#
#   statefp10 tractce10   tract  Tot_Pop Family_Inc Other_Race
# 0        17    843500  843500  10079.0      217.0     7362.0
# 1        17    843500  843500  10079.0      217.0     7362.0
# 2        17    843500  843500  10079.0      217.0     7362.0
# 3        17    843500  843500  10079.0      217.0     7362.0
# 4        17    843500  843500  10079.0      217.0     7362.0
#
# [5 rows x 43 columns]

# %%
print(acs_df['tract'].dtypes)
crime_trk['tractce10'].dtypes
print(acs_trk['tract'].nunique())
acs_trk.shape
# Out:
# object
# 1319
# (1319, 4)

# %%
crm_blkgp = crime.merge(acs_df, left_on='tractce10', right_on='tract')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-317-fcf7ab15b356> in <module>()
# ----> 1 crm_blkgp = crime.merge(acs_df, left_on='tractce10', right_on='tract')
#
# /anaconda3/lib/python3.6/site-packages/geopandas/geodataframe.py in merge(self, *args, **kwargs)
#     489
#     490     def merge(self, *args, **kwargs):
# --> 491         result = DataFrame.merge(self, *args, **kwargs)
#     492         geo_col = self._geometry_column_name
#     493         if isinstance(result, DataFrame) and geo_col in result:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     844                         right_keys.append(rk)
#     845                     if lk is not None:
# --> 846                         left_keys.append(left._get_label_or_level_values(lk))
#     847                         join_names.append(lk)
#     848                     else:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1705             values = self.axes[axis].get_level_values(key)._values
#    1706         else:
# -> 1707             raise KeyError(key)
#    1708
#    1709         # Check for duplicates
#
# KeyError: 'tractce10'

# %% [markdown]
# # Question 3

# %%
def geocoded_blocktract(lon,lat):
    query = cg.coordinates(x=lon, y=lat)
    tract = query.get('Census Tracts')[0].get('TRACT')
    blkgrp = query.get('2010 Census Blocks')[0].get('BLKGRP')
    return tract

# %%
cr = crime[1:1000]
# cr.head()

# %%
# crime['BlockGroup'] = geocoded_blocktract(crime['latitude'],crime['longitude'])
cr['BlockGroup'] = geocoded_blocktract(cr['longitude'],cr['latitude'])
# Out:
# 836700

# %%
for index, row in cr.iterrows():
#     print(row['c1'], row['c2'])
    cr.loc[index,'BlockGroup'] = geocoded_blocktract(row['longitude'],row['latitude'])
# Out:
# 836700
# 381400
# 530300
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-292-65df16413135> in <module>()
#       1 for index, row in cr.iterrows():
#       2 #     print(row['c1'], row['c2'])
# ----> 3     cr.loc[index,'BlockGroup'] = geocoded_blocktract(row['longitude'],row['latitude'])
#
# <ipython-input-282-0ae04d3ada78> in geocoded_blocktract(lon, lat)
#       1 def geocoded_blocktract(lon,lat):
# ----> 2     query = cg.coordinates(x=lon, y=lat)
#       3     tract = query.get('Census Tracts')[0].get('TRACT')
#       4     blkgrp = query.get('2010 Census Blocks')[0].get('BLKGRP')
#       5     print(tract)
#
# /anaconda3/lib/python3.6/site-packages/censusgeocode/censusgeocode.py in coordinates(self, x, y, **kwargs)
#     113         }
#     114
# --> 115         return self._fetch('coordinates', fields, **kwargs)
#     116
#     117     def address(self, street, city=None, state=None, zipcode=None, **kwargs):
#
# /anaconda3/lib/python3.6/site-packages/censusgeocode/censusgeocode.py in _fetch(self, searchtype, fields, **kwargs)
#      89
#      90         try:
# ---> 91             with requests.get(url, params=fields, timeout=kwargs.get('timeout')) as r:
#      92                 content = r.json()
#      93                 if "addressMatches" in content.get('result', {}):
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1712             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1713         else:
# -> 1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# KeyboardInterrupt:

# %%
cr
# Out:
#       arrest  beat                      block case_number community_area  \
# 1       True  1221    007XX N SACRAMENTO BLVD    JA545986             23
# 5       True  0215            003XX E 47TH ST    JA522842             38
# 7      False  0524        117XX S SANGAMON ST    JB140548             53
# 8      False  2234           011XX W 111TH ST    JB107989             75
# 9      False  1834       004XX N MICHIGAN AVE    JB108319              8
# 10      True  1014        016XX S HARDING AVE    JB108320             29
# 11     False  0222      047XX S LAKE PARK AVE    JB108379             39
# 13     False  2223         097XX S HALSTED ST    JB108166             73
# 14     False  2411          025XX W TOUHY AVE    JB108139              2
# 16      True  1612         062XX N OLCOTT AVE    JB108167             10
# 20     False  0313            004XX E 63RD ST    JB108191             42
# 21     False  2222            014XX W 87TH ST    JB108181             71
# 23      True  0611      079XX S HERMITAGE AVE    JB108348             71
# 24     False  1013        024XX S HARDING AVE    JB108175             30
# 25     False  2032        050XX N ASHLAND AVE    JB108327              3
# 26     False  0912            020XX W 32ND ST    JB108407             59
# 29     False  1723   047XX N CENTRAL PARK AVE    JB108235             14
# 30     False  0512         105XX S FOREST AVE    JB108242             49
# 31     False  0312    063XX S ST LAWRENCE AVE    JA351722             42
# 32     False  0312    063XX S ST LAWRENCE AVE    JA351722             42
# 33     False  0411  079XX S SOUTH CHICAGO AVE    JA352359             46
# 34     False  0813            041XX W 58TH PL    JB108172             62
# 38     False  1724         040XX N KEDZIE AVE    JB108202             16
# 40     False  1133        038XX W FLOURNOY ST    JB108239             26
# 41     False  1122   006XX N CENTRAL PARK AVE    JB108182             23
# 44     False  2413        061XX N ROCKWELL ST    JB108170              2
# 45     False  1233      013XX W WASHBURNE AVE    JB108211             28
# 46     False  1623         048XX N LINDER AVE    JB109455             11
# 47     False  0421       077XX S KINGSTON AVE    JB108228             43
# 48     False  1811       022XX N SEMINARY AVE    JB108174              7
# ...      ...   ...                        ...         ...            ...
# 1602                     WOODLAWN  4.051574e+07   28960.059037  February-2018
# 1603  BRIGHTON PARK,MCKINLEY PARK  7.589279e+07   36537.134306  February-2018
# 1604             CHATHAM,BURNSIDE  8.232067e+07   42006.945009  February-2018
# 1605                       AUSTIN  1.700378e+08   55473.345911  February-2018
# 1606                 LOGAN SQUARE  7.125681e+07   36361.508518  February-2018
# 1607              RUSH & DIVISION  3.489576e+06    8503.033133  February-2018
# 1608                       AUSTIN  1.700378e+08   55473.345911  February-2018
# 1609                  ROGERS PARK  5.125990e+07   34052.397576  February-2018
# 1610                GARFIELD PARK  8.997607e+07   44460.919220  February-2018
# 1611                    WEST LOOP  5.294506e+07   43907.671821  February-2018
# 1612         IRVING PARK,AVONDALE  5.529060e+07   34261.933404  February-2018
# 1613                SOUTH CHICAGO  9.327219e+07   52435.979431     March-2018
# 1615                GARFIELD PARK  8.997607e+07   44460.919220  February-2018
# 1616  WASHINGTON HEIGHTS,ROSELAND  1.343137e+08   56632.795429  February-2018
# 1617                    WEST LOOP  5.294506e+07   43907.671821  February-2017
# 1618                  BRONZEVILLE  4.600462e+07   31027.053671     March-2017
# 1619                        OHARE  3.718356e+08  173625.984660       May-2017
# 1620                     WOODLAWN  4.051574e+07   28960.059037      June-2017
# 1621        WICKER PARK,WEST TOWN  5.850773e+07   46673.620546  November-2017
# 1622                     BUCKTOWN  2.880076e+07   26109.107610  November-2017
# 1625         IRVING PARK,AVONDALE  8.961138e+07   49083.224094  February-2018
# 1626                 PORTAGE PARK  1.101961e+08   46520.642138  February-2018
# 1627                 LOGAN SQUARE  7.125681e+07   36361.508518  February-2018
# 1629                  RIVER NORTH  3.876644e+07   31506.037810  February-2018
# 1630                SOUTH CHICAGO  9.327219e+07   52435.979431  February-2018
#
#      BlockGroup
# 1        836700
# 5        381400
# 7        530300
# 8        750100
# 9        081403
# 10       292400
# 11       390700
# 13       730500
# 14       020200
# 16       100300
# 20       420700
# 21       711100
# 23       710500
# 24       300500
# 25       031000
# 26       840300
# 29       140602
# 30       490902
# 31       420700
# 32       420700
# 33       460500
# 34          NaN
# 38          NaN
# 40          NaN
# 41          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# ...         ...
# 1596        NaN
# 1598        NaN
# 1599        NaN
# 1600        NaN
# 1601        NaN
# 1602        NaN
# 1603        NaN
# 1604        NaN
# 1605        NaN
# 1606        NaN
# 1607        NaN
# 1608        NaN
# 1609        NaN
# 1610        NaN
# 1611        NaN
# 1612        NaN
# 1613        NaN
# 1615        NaN
# 1616        NaN
# 1617        NaN
# 1618        NaN
# 1619        NaN
# 1620        NaN
# 1621        NaN
# 1622        NaN
# 1625        NaN
# 1626        NaN
# 1627        NaN
# 1629        NaN
# 1630        NaN
#
# [999 rows x 30 columns]

# %%
from osgeo import ogr

#Assumes your points and shapefile are already in the same datum/projection
# shapefile_name = "census_tracts.shp"
shapefile_name = "/Users/parthkhare/Desktop/MSCAPP Quarters/Quarter 2/CS Q2/Project/Data/Chicago Admin Boundaries/Census Tracts_801/CTracts_801.shp"

#This version takes a long_lat_list of the form below and a shapefile name
def getCensusTracts(long_lat_list, shapefile_name):
    driver = ogr.GetDriverByName("ESRI Shapefile")
    dataSource = driver.Open(shapefile_name, 0)
    layer = dataSource.GetLayer()
    results_dict = {}
    i = 0
    for feature in layer:
        geom = feature.GetGeometryRef()
        i += 1
        for pt in long_lat_list:
            gid = pt[0]
            lon = pt[1]
            lat = pt[2]
            point = ogr.Geometry(ogr.wkbPoint)
            point.AddPoint(lon, lat)
            if point.Within(geom) == True:
                feat_id = feature.GetField("fips")
                if gid in results_dict and feat_id not in results_dict[gid]:
                    results_dict[gid].append(feat_id)
                else:
                    results_dict[gid] = [feat_id]
    for pt in long_lat_list:
        gid = pt[0]
        lon = pt[1]
        lat = pt[2]
        if gid not in results_dict:
            results_dict[gid] = ['NA']
    return results_dict


#Where elements are [id, long, lat]
long_lat_list = [[1, -87.5, 35.5],[2, -78.446, 41.353]]
# long_lat_list = [[1, -87.702169158, 41.894475919],[2, -87.619098999, 41.809342727]]

results_dict = getCensusTracts(long_lat_list, shapefile_name)
#results_dict returns a dictionary where {'id: list_of_fips_codes}
print(results_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-302-03cbbf9f6b13> in <module>()
#      40 long_lat_list = [[1, -87.702169158, 41.894475919],[2, -87.619098999, 41.809342727]]
#      41
# ---> 42 results_dict = getCensusTracts(long_lat_list, shapefile_name)
#      43 #results_dict returns a dictionary where {'id: list_of_fips_codes}
#      44 print(results_dict)
#
# <ipython-input-302-03cbbf9f6b13> in getCensusTracts(long_lat_list, shapefile_name)
#      22             point.AddPoint(lon, lat)
#      23             if point.Within(geom) == True:
# ---> 24                 feat_id = feature.GetField("fips")
#      25                 if gid in results_dict and feat_id not in results_dict[gid]:
#      26                     results_dict[gid].append(feat_id)
#
# /anaconda3/lib/python3.6/site-packages/osgeo/ogr.py in GetField(self, fld_index)
#    4747             fld_index = self.GetFieldIndex(fld_index)
#    4748         if (fld_index < 0) or (fld_index > self.GetFieldCount()):
# -> 4749             raise ValueError("Illegal field requested in GetField()")
#    4750         if not (self.IsFieldSet(fld_index)) or self.IsFieldNull(fld_index):
#    4751             return None
#
# ValueError: Illegal field requested in GetField()

# %%
long_lat_list = [1,-87.702169158,41.894475919],[2,-87.619098999,41.809342727],[3,-87.645661144,41.68073915]
# Out:
# [[1, -87.5, 35.5], [2, -78.446, 41.353]]

# %%
cr['BlockGroup'].nunique()
# Out:
# 1

# %%
cr['longitude'],cr['latitude']
# Out:
# (1       -87.702169158
#  5       -87.619098999
#  7       -87.645661144
#  8        -87.65053259
#  9       -87.624109917
#  10      -87.723691271
#  11      -87.591967028
#  13      -87.643093654
#  14       -87.69390481
#  16      -87.813664825
#  20      -87.615319321
#  21      -87.658739723
#  23      -87.667066613
#  24      -87.723405898
#  25      -87.669569703
#  26      -87.675869803
#  29      -87.718216495
#  30      -87.616090149
#  31       -87.61078722
#  32       -87.61078722
#  33      -87.584233158
#  34      -87.726117873
#  38      -87.708032917
#  40      -87.721572678
#  41      -87.716231674
#  44      -87.694615236
#  45      -87.659964172
#  46       -87.76504738
#  47      -87.562657533
#  48      -87.655942683
#              ...
#  1596    -87.700548903
#  1598    -87.664962595
#  1599    -87.661221497
#  1600    -87.704967405
#  1601    -87.765064273
#  1602    -87.603396522
#  1603    -87.691801206
#  1604    -87.603228669
#  1605    -87.757066697
#  1606    -87.714968502
#  1607    -87.627683859
#  1608     -87.75762248
#  1609    -87.662241448
#  1610    -87.707351971
#  1611    -87.640660777
#  1612    -87.721184762
#  1613    -87.546637154
#  1615    -87.739215712
#  1616    -87.632529294
#  1617    -87.652768298
#  1618    -87.619247778
#  1619    -87.905227221
#  1620    -87.590420873
#  1621    -87.646497181
#  1622    -87.683649714
#  1625     -87.70093887
#  1626    -87.758250282
#  1627    -87.693444139
#  1629    -87.626238686
#  1630     -87.56373736
#  Name: longitude, Length: 999, dtype: object, 1       41.894475919
#  5       41.809342727
#  7        41.68073915
#  8       41.692258729
#  9       41.890384236
#  10      41.858283017
#  11      41.809297059
#  13       41.71716022
#  14       42.01220081
#  16      41.993999504
#  20      41.780243493
#  21       41.73585412
#  23      41.749780682
#  24      41.847364829
#  25      41.973742771
#  26      41.835834607
#  29      41.967114799
#  30      41.703116806
#  31      41.779630545
#  32      41.779630545
#  33      41.750530118
#  34      41.786815713
#  38      41.954505026
#  40      41.872585788
#  41      41.892680776
#  44      41.993047583
#  45      41.866099449
#  46      41.968415429
#  47      41.754953934
#  48      41.922543983
#              ...
#  1596     41.77307974
#  1598    41.938837143
#  1599    41.886609082
#  1600    41.866417614
#  1601    41.909384533
#  1602    41.776016248
#  1603    41.809554966
#  1604    41.729378526
#  1605    41.880348999
#  1606    41.924627849
#  1607    41.896685066
#  1608    41.883477487
#  1609     42.00552183
#  1610    41.882780879
#  1611    41.865397377
#  1612    41.935135864
#  1613    41.742424658
#  1615    41.870529664
#  1616     41.68654917
#  1617    41.881688266
#  1618    41.826989318
#  1619    41.976290414
#  1620    41.774212402
#  1621    41.891198145
#  1622    41.929314934
#  1625    41.952139077
#  1626    41.955110574
#  1627    41.914526412
#  1629    41.892507682
#  1630    41.747395139
#  Name: latitude, Length: 999, dtype: object)

# %%
# l = []
# for cord in crime['geometry']:
#     print(cord)
#     gc = cg.coordinates(x=-87.62384, y=41.85406)
#     tract = gc.get('Census Tracts')[0].get('TRACT')
#     print(tract)

# %%
t = cg.coordinates(x=-87.62384, y=41.85406)

# %%
print(t.get('Census Tracts')[0].get('TRACT'))
print(t.get('2010 Census Blocks')[0].get('BLKGRP'))
# Out:
# 330100
# 4

# %%
t.get('2010 Census Blocks')
# Out:
# [{'AREALAND': 9662,
#   'AREAWATER': 0,
#   'BASENAME': '4055',
#   'BLKGRP': '4',
#   'BLOCK': '4055',
#   'CENT': (-87.6234442, 41.8536206),
#   'CENTLAT': '+41.8536206',
#   'CENTLON': '-087.6234442',
#   'COUNTY': '031',
#   'FUNCSTAT': 'S',
#   'GEOID': '170313301004055',
#   'INTPT': (-87.6234442, 41.8536206),
#   'INTPTLAT': '+41.8536206',
#   'INTPTLON': '-087.6234442',
#   'LSADC': 'BK',
#   'LWBLKTYP': 'L',
#   'MTFCC': 'G5040',
#   'NAME': 'Block 4055',
#   'OBJECTID': 3356047,
#   'OID': 210404038769610,
#   'STATE': '17',
#   'STGEOMETRY.AREA': 17428.229,
#   'STGEOMETRY.LEN': 573.30286,
#   'SUFFIX': '',
#   'TRACT': '330100'}]

# %%
# Out:
# '330100'

# %% [markdown]
# # Question 4

# %% [markdown]
# ### Question 4.1

# %%
# Geocode the Address
add = cg.onelineaddress('2111 S Michigan Ave, Chicago, US')
# Extract Lat Long from the query 
incident = Point(add[0].get('coordinates').get('x'), add[0].get('coordinates').get('y'))
qry = nbh.contains(incident)
# Identify Neighborhood Polygon containing the geocded address 
geo = [i for i, x in enumerate(s) if x]
print(nbh.iloc[geo]) # Near South Side
nbh.geometry[63]
# Out:
#           PRI_NEIGH        SEC_NEIGH    SHAPE_AREA     SHAPE_LEN  \
# 63  Near South Side  NEAR SOUTH SIDE  3.425258e+07  26884.589204
#
#                                              geometry
# 63  POLYGON ((-87.61665903158642 41.85779360897209...

# %% [markdown]
# ### Question 4.2

# %%
crime_thft = crime[crime.primary_type == 'THEFT']
crime_thft_gp = crime_thft.groupby(['PRI_NEIGH','primary_type'])['case_number'].agg('count').reset_index()
loc = ['Garfield Park', 'Uptown']
crime_thft_lc = crime_thft_gp[crime_thft_gp.PRI_NEIGH.isin(loc)]
crime_thft_lc['PercentTheft'] = (crime_thft_lc['case_number']*100)/crime_thft_gp.case_number.sum()
crime_thft_lc
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         PRI_NEIGH primary_type  case_number  PercentTheft
# 31  Garfield Park        THEFT         2489      1.960939
# 86         Uptown        THEFT         1956      1.541019

# %%
crime_batt = crime[crime.primary_type == 'BATTERY']
crime_batt_gp = crime_batt.groupby(['PRI_NEIGH','primary_type'])['case_number'].agg('count').reset_index()
loc = ['Garfield Park', 'Uptown']
crime_batt_lc = crime_batt_gp[crime_batt_gp.PRI_NEIGH.isin(loc)]
crime_batt_lc['PercentBatt'] = (crime_batt_lc['case_number']*100)/crime_batt_gp.case_number.sum()
crime_batt_lc
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#         PRI_NEIGH primary_type  case_number  PercentBatt
# 31  Garfield Park      BATTERY         4569     4.635426
# 86         Uptown      BATTERY         1370     1.389918

# %%
#B01003_001E  : total pop, 
#B02001_001E  : race, 
#B19101_001E  : FAMILY INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS, 
#B19083_001E  : GINI INDEX OF INCOME INEQUALITY, 
#B19127_001E : AGG FAMILY INCOME IN THE PAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS

# %%
# Get Data from URL {API} : Other method
from census_area import Census
c = Census("6672193bb01252a3977177729df914e5a8f7f0e5")
finc = c.acs5.state_place_blockgroup(('NAME', 'B19101_001E'), 17, 14000)
finc_df = pd.DataFrame(finc)
