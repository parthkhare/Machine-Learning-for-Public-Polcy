# %% [markdown]
# # <span style="color:blue"> Further Immproving ML Pipeline II: Assignment V </span>

# %% [markdown]
# ## Libraries & Helper Function

# %%
import pandas as pd
import seaborn as sns
import warnings
import numpy as np
import scipy as sp
import graphviz 
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
from IPython.display import display

from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score as accuracy
from sklearn.preprocessing import normalize, scale
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier, OrthogonalMatchingPursuit, RandomizedLogisticRegression
from sklearn.neighbors.nearest_centroid import NearestCentroid
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
# from sklearn.cross_validation import train_test_split

# %%
# Helper Function
import sys
sys.path.append('/Users/parthkhare/Parth_Repos/Machine-Learning-for-Public-Polcy/Improving_Pipeline_II/helper')
import MLPreprocess_helper_mlpp as mh
import MLClassifier_helper_mlpp as cl

# %%
# Import Data
filepath = "data/projects_2012_2013.csv"
df = mh.import_data(filepath)

# %% [markdown]
# ## II A: Explore Features
#
# Bird' s eye view of how the data looks like.
# Customised by variable type
#
# Broad level data exploration on:
# - Feature Summary (describe)
# - Compartiive feature distribution (bxoplot)

# %%
# Data Exploration: Stage I
mh.explore_features(df)
# Out:
# 'Feature Summary:'
#        school_ncesid  school_latitude  school_longitude  \
# count   1.157430e+05    124976.000000     124976.000000
# mean    2.448448e+11        36.827284        -95.859299
# std     1.644728e+11         4.963669         18.392876
# min     1.000050e+10        18.249140       -171.690554
# 25%     6.344101e+10        33.872504       -117.806418
# 50%     2.200870e+11        36.617410        -90.101563
# 75%     3.704880e+11        40.676156        -80.713740
# max     6.100010e+11        65.672562        -66.628036
#
#        total_price_including_optional_support  students_reached
# count                           124976.000000     124917.000000
# mean                               654.011811         95.445760
# std                               1098.015854        163.481912
# min                                 92.000000          1.000000
# 25%                                345.810000         23.000000
# 50%                                510.500000         30.000000
# 75%                                752.960000        100.000000
# max                             164382.840000      12143.000000
# Individual Feature Distribution I: Birds Eye

# %% [markdown]
# ## II B: Explore Features (categorical)
#
# Bird' s eye view of how the data looks like.
# Broad level data exploration on:
# - Categorical Variables (histograms)

# %%
# Specify dtypes
cat_var = ['school_city', 'school_state','school_metro', 'school_district', 'school_county', 'school_charter',
       'school_magnet', 'teacher_prefix', 'primary_focus_subject','primary_focus_area', 'secondary_focus_subject',
        'secondary_focus_area','resource_type', 'poverty_level', 'grade_level','eligible_double_your_impact_match']
cont_var = ['total_price_including_optional_support', 'students_reached']
date_var = ['date_posted', 'datefullyfunded']

# Categorical Summary
print('Number of Projects:',df['projectid'].nunique())
print('Number of Schools:',df['schoolid'].nunique())
print('Number of Teachers:',df['teacher_acctid'].nunique())
print('Number of Cities:',df['school_city'].nunique())
print('Number of School Districts:',df['school_district'].nunique())

# Plot
f, axes = plt.subplots(2, 3, figsize=(14, 6))
f.subplots_adjust(hspace=0.4, wspace=0.4)
ax = sns.countplot(x="resource_type", hue="poverty_level", data=df, ax=axes[0, 0])
ax = sns.countplot(x="resource_type", hue="grade_level", data=df, ax=axes[0, 1])
ax = sns.countplot(x="resource_type", hue="school_metro", data=df, ax=axes[0, 2])
ax = sns.countplot(x="resource_type", hue="eligible_double_your_impact_match", data=df, ax=axes[1, 0])
ax = sns.countplot(x="resource_type", hue="school_charter", data=df, ax=axes[1, 1])
ax = sns.countplot(x="resource_type", hue="school_magnet", data=df, ax=axes[1, 2])
# f.suptitle('Demand of Resource Type: comparison')
plt.tight_layout()
print('Approximately 1 school district per city')
# Out:
# Number of Projects: 124976
# Number of Schools: 29947
# Number of Teachers: 77013
# Number of Cities: 5955
# Number of School Districts: 5970
# Approximately 1 school district per city

# %% [markdown]
# ## II C: Explore Features (date/time)
#
# Broad level data exploration on:
# - Donation response time
# - Total Price Including and Excludiong Optional Support

# %%
# Convert to Date
date_var = ['date_posted', 'datefullyfunded']
df = mh.trnf_dtype(df, var_list=date_var, to_type='date')
df['resp_time'] = df['datefullyfunded'] - df['date_posted']

# Plot donation completion distribution
fig, ax = plt.subplots(1, 1, figsize=(10,5))
ax = (df['resp_time'] / np.timedelta64(1, 'D')).plot.kde(color='r')
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, 10))
ax.set_xlabel("Days")
ax.set_title("Donation Response time")
# fig.savefig('/charts/donation_response_time.png')
# Out:
# Text(0.5, 1.0, 'Donation Response time')

# %%
# Observe trends across months
df['month_posted'] = df['date_posted'].dt.month
df['year_posted'] = df['date_posted'].dt.year

# Total Price Including Support
sns.factorplot(x='month_posted', y ='total_price_including_optional_support', col='year_posted', data=df)
plt.ylim(0,1500)
plt.title('Total Price Including Optional Support by Year, Month')
# Out:
# Text(0.5, 1.0, 'Total Price Including Optional Support by Year, Month')

# %% [markdown]
# ## III: Explore Feature Interactions
#
# Explore feature interactions amongst each other. Helps in weeding verbose (highly correlated variables). Evaluated through
# - Correlation heatmap
# - Pairwsie plots for continous attributes

# %%
# Data Exploration: Pairwise
cont_var = ['total_price_including_optional_support', 'students_reached']
df = mh.trnf_dtype(df, var_list=cont_var, to_type='cont')
mh.explore_finteractions(df, cont_var)
# Out:
# Pairwise Feature Distribution: Variable Histograms
# Pairwise Feature Distribution: Pairplot

# %% [markdown]
# ## <span style="color:red"> Pit Stop: Observations from School Donors Data </span>
#
# Following quick observation may be drawn for data on 124 thousand project proposal over 2 years.
#
# - Multi-modal Dononation response time stands out
#     - particularly the drop in number of donations for around 60days
#     - this implies that most of funding were done within this window and therefore we can expect a baseline in our model
#
# - Relatively higher contribution in supplies & technology
#     - relatively higher overall donation in urban areas
#     - higher donation made in high poverty schools
#     - higher donations made in pre-K2 grades
#
# - Total pricing and students reached attributes show a near *Gamma* distribution
#     - which *supports* trying a non-parametric/Machine learning based method
#     - conventional regression frameworks (in some cases even GLMM) might be inept in accurately extracting variance in such cases
#     - pairwise correlation between them can be indicative of more the students reached more donation made
#
# - Average Monhtly Funding (with support) aorund $400-$500, without much seasonal variation.
# - Sizebale outliers, particular to the range of over $1500K in November 2013
#
# Caveat
# + *A caevat of the given process is not discerning categorical and continous variables. It is likely that the given datasets might have mispscified/unusable data types. So, it helpful to in the first stage throw in the variables alltogether and use these results to understand the nature and use of these feature for the subjective analysis, expeditiously*

# %% [markdown]
# ## IV: Feature Engeneering
#
# ### Variable Treatment
# - Missing Value
# - Dummy Variable
# - Binary Bins
# - Normalising outlier distribution
# - Create features
#
# The following section identifies variables under these heads.
# The training data in the model would be modified dynamically during model run

# %% [markdown]
# ### Missing Values
#
# - View a summery of missing proportion by columns
# - Replace missing values by mean/median as specified
#     - specify mean=False for median
# Caveat
# + *Missing data can be present in different forms based on data or file type (na, null, NA ,NaN :0/0 forms, '.'). Getting a sense of meaning of the feature & format of the file type is helpfu. E.g. Stata uses '.', R uses 'NA' *

# %%
# Get Missing Data Summary
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print('Missing data summary', display(missing_data.head(20)))

# Identified parameters for training data
missing_var = ['students_reached']
# Out:
#                          Total   Percent
# secondary_focus_subject  40556  0.324510
# secondary_focus_area     40556  0.324510
# school_metro             15224  0.121815
# school_ncesid             9233  0.073878
# school_district            172  0.001376
# students_reached            59  0.000472
# resource_type               17  0.000136
# primary_focus_area          15  0.000120
# primary_focus_subject       15  0.000120
# grade_level                  3  0.000024
# school_city                  0  0.000000
# school_county                0  0.000000
# school_longitude             0  0.000000
# school_latitude              0  0.000000
# schoolid                     0  0.000000
# school_state                 0  0.000000
# teacher_acctid               0  0.000000
# year_posted                  0  0.000000
# school_charter               0  0.000000
# school_magnet                0  0.000000
# Missing data summary None

# %% [markdown]
# ### Missing treatment summary
# 59 missing values student_reached treated by mean replacement.
# Ideally, given the right skewed distribution mean is not recommended, but the missing % is less than 0.001% of data
# Rest missing in categorical variable. Not imputing as of now, can use hot deck or association rules if required.

# %% [markdown]
# ### Generate features

# %%
# Correspondence Hierarchy
# Identifying criteria for focus area vs subject 
print(df.groupby(['primary_focus_area',"primary_focus_subject"]).size())
print(df.groupby(['secondary_focus_area',"secondary_focus_subject"]).size())
# Given cocurrence, choosing to keep subject rather than area

# Identifying criteria for focus area vs subject 
print(df.groupby(['school_city']).size().sort_values(ascending=False).head(10))
# treat larger cities separately: based on their potential to signal
maj_cities = df.groupby(['school_city']).size().sort_values(ascending=False).head(10)

# Also developing features based on teacher's gender {clubbing 2 separate cat might help}
# Parsing from teacher prefix
print(df.groupby(['teacher_prefix']).size())
# Out:
# primary_focus_area   primary_focus_subject
# Applied Learning     Character Education       2249
#                      College & Career Prep     1217
#                      Community Service          221
#                      Early Development         2618
#                      Extracurricular            480
#                      Other                     1809
#                      Parent Involvement         128
# Health & Sports      Gym & Fitness             1281
#                      Health & Wellness         1450
#                      Nutrition                  190
#                      Sports                     574
# History & Civics     Civics & Government        428
#                      Economics                  491
#                      History & Geography       2701
#                      Social Sciences           1538
# Literacy & Language  ESL                       1604
#                      Foreign Languages          898
#                      Literacy                 37408
#                      Literature & Writing     16141
# Math & Science       Applied Sciences          5825
#                      Environmental Science     4835
#                      Health & Life Science     4185
#                      Mathematics              16859
# Music & The Arts     Music                     3931
#                      Performing Arts           1682
#                      Visual Arts               5870
# Special Needs        Special Needs             8348
# dtype: int64
# secondary_focus_area  secondary_focus_subject
# Applied Learning      Character Education         2337
#                       College & Career Prep       1879
#                       Community Service            526
#                       Early Development           3599
#                       Extracurricular              832
#                       Other                       1889
#                       Parent Involvement           500
# Health & Sports       Gym & Fitness                754
#                       Health & Wellness           1582
#                       Nutrition                    270
#                       Sports                       402
# History & Civics      Civics & Government          771
#                       Economics                    456
#                       History & Geography         2918
#                       Social Sciences             2636
# Literacy & Language   ESL                         4698
#                       Foreign Languages            371
#                       Literacy                   12598
#                       Literature & Writing       12389
# Math & Science        Applied Sciences            3380
#                       Environmental Science       2997
#                       Health & Life Science       3103
#                       Mathematics                12513
# Music & The Arts      Music                       1129
#                       Performing Arts             2438
#                       Visual Arts                 2236
# Special Needs         Special Needs               5217
# dtype: int64
# school_city
# Los Angeles      5747
# Chicago          3467
# Houston          2879
# Brooklyn         2561
# Bronx            1947
# New York         1484
# Philadelphia     1455
# Indianapolis     1294
# San Francisco    1135
# Charlotte        1057
# dtype: int64
# teacher_prefix
# Dr.         2
# Mr.     16273
# Mrs.    60190
# Ms.     48511
# dtype: int64

# %% [markdown]
# ### Dummy labels for categorial features

# %%
# Identified Parameters for training data
dum_var = ['school_district','school_city','school_metro','teacher_prefix','primary_focus_subject','school_county',
           'primary_focus_subject','secondary_focus_subject','resource_type','poverty_level','grade_level']

# %% [markdown]
# ### Binary bins

# %%
# Identified Parameters for training data
bin_var = ['eligible_double_your_impact_match','school_charter','school_magnet']

# %% [markdown]
# ### Normalising outlier distribution

# %%
# Identified Parameters for training data
norm_var = ['total_price_including_optional_support', 'students_reached']

# %% [markdown]
# ### Outliers/Dropping variables
# No strong pairwise correlation leading to a multinollinearity like situation.There might be correlation between total price and students reached, if outliers are removed, but considering the outliers value as part of sample for now.
#
# #### Note on Outliers
# NOTE: *Treating outliers did not seem particularly useful for the data in question. Outliers in donation and students are plausible. If however required Z-scaores are a good way to examine individual feature distirbutions.*
# `from scipy import stats
# z1 = np.abs(stats.zscore(df))
# z = np.abs(stats.zscore(df_c))`
# One can further apply a threshold on the Z-value to filter our outlier.

# %%
# Test Feature Engeneergin Run
# xtr = cl.feature_eng(df, missing_var, cat_var, bin_var, norm_var, maj_cities)
#xtr.head(10)
# Out:
# Index(['projectid', 'teacher_acctid', 'schoolid', 'school_ncesid',
#        'school_latitude', 'school_longitude', 'school_city', 'school_state',
#        'school_metro', 'school_district', 'school_county', 'school_charter',
#        'school_magnet', 'teacher_prefix', 'primary_focus_subject',
#        'primary_focus_area', 'secondary_focus_subject', 'secondary_focus_area',
#        'resource_type', 'poverty_level', 'grade_level',
#        'total_price_including_optional_support', 'students_reached',
#        'eligible_double_your_impact_match', 'date_posted', 'datefullyfunded',
#        'resp_time', 'month_posted', 'year_posted'],
#       dtype='object')

# %%
# Judgement: the model will be tested on imbalanced panel this way, the last testing period will less than 6 month/1yr
for prediction_window in prediction_windows:
        print('prediction_window:',prediction_window)
        train_start_time = start_time_date
        train_end_time = train_start_time + relativedelta(months=+prediction_window) - relativedelta(days=+1)
        print('\n')
        print(train_start_time)

        print('train_end_time 1:', train_end_time) 
        
        while train_end_time + relativedelta(months=+prediction_window)<=end_time_date:
            # Considering effects of intervention to take place 
            test_start_time = train_end_time + relativedelta(days=+observation_period)
            test_end_time = test_start_time + relativedelta(months=+prediction_window) - relativedelta(days=+1)
            
            print('training date range:', train_start_time, train_end_time) 
            print('testing date range:', test_start_time, test_end_time)
            
            train_end_time += relativedelta(months=+prediction_window)
            print('train_end_time 2:', train_end_time) 
            print('\n'
# Out:
# prediction_window: 6
#
#
# 2012-01-01 00:00:00
# train_end_time 1: 2012-06-30 00:00:00
# training date range: 2012-01-01 00:00:00 2012-06-30 00:00:00
# testing date range: 2012-08-29 00:00:00 2013-02-27 00:00:00
# train_end_time 2: 2012-12-30 00:00:00
#
#
# training date range: 2012-01-01 00:00:00 2012-12-30 00:00:00
# testing date range: 2013-02-28 00:00:00 2013-08-27 00:00:00
# train_end_time 2: 2013-06-30 00:00:00
#
#
# training date range: 2012-01-01 00:00:00 2013-06-30 00:00:00
# testing date range: 2013-08-29 00:00:00 2014-02-27 00:00:00
# train_end_time 2: 2013-12-30 00:00:00
#
#
# prediction_window: 12
#
#
# 2012-01-01 00:00:00
# train_end_time 1: 2012-12-31 00:00:00
# training date range: 2012-01-01 00:00:00 2012-12-31 00:00:00
# testing date range: 2013-03-01 00:00:00 2014-02-28 00:00:00
# train_end_time 2: 2013-12-31 00:00:00

# %% [markdown]
# ## <span style="color:red"> Pit Stop: Summary of variable treatment & feature engeneering </span>
#
# - Excluding ID variables (projectid, school_ncesid)
#     - there are 29947 schools and 77013 teachers overall
#     - that means same teachers & schools received got multiple grants
#     - can signal donation accquiring capacity
#
# - Feature Generation I: using from prefix
#     - Gender variable on teachers
#     - Considered using selecting variables by qualifications: but techers with Dr's less than 1% of data
#
# - Feature Generation II: major cities
#     - Considered high frequency cities
#     - Quickly googled highest frequency ones for having high population
#
# - Hierarchial geographies: geographical identifiers (lat, long, state, county, city)
#     - Multiple geographical indicators indicating same geography
#     - Choosing geographical resolution
#         - Proportionate to the data density choose higher resolution (but lower than lat,long)
#         - Corresponding number of cities (5955) by school district (5970)
#         - But given difference in rel frequency using both
#         - Keeping School district as it might be a better policy indicative
#
# - Excluding hierarchial variables 2: Focus Area vs Subject (remove focus_area)
#     - Checking if focus area and focus subject have 1-1 mapping
#     - No they do not
#     - Retain category with higher resolution
#
# Hierarchial variables might drain variance from each another so keeping retaining singular types
#
# NOTE: *Instead of adding transformed variables to the same data frame, the current implementation transforms into a new dataframe to reduce steps in variable name specification in model run. This acts a check-post to avoid re-running processes from start*

# %% [markdown]
# # V: Finalizing Model Dataset
#
# - Set final model variables
#     - Check for any further interactions
# - Target variable defined as finding funding within 60 days
# - Test the model in 6 months rolling window
#     - Deselect 60 days prior to the test phase beginning
#
# Minimal base case run for constrained by KNN timing

# %%
# Select Model Data
model_var = ['school_district','school_city','school_charter','school_magnet','teacher_prefix','school_county',
             'primary_focus_subject','secondary_focus_subject','resource_type','poverty_level', 'grade_level',
             'total_price_including_optional_support','students_reached','eligible_double_your_impact_match',
             'date_posted','datefullyfunded','school_metro','resp_time']
df_m = df[model_var]

# %%
# Based on model context
observation_period = 60 
observation_window = str(observation_period) +' days'

# progressive train on 6 month window
prediction_windows = [6,12]

# Create target label variable
df_m['fund_60day'] = (df_m['resp_time'] < observation_window).astype('int').astype('category')

# Remove label originators
df_m = df_m.drop(labels=['datefullyfunded','resp_time'], axis=1)
df_m.head()
# Out:
#                 school_district    school_city school_charter school_magnet  \
# 0         Pershing Elem Network        Chicago              f             f
# 1  Ventura Unif School District        Ventura              f             f
# 2     Los Angeles Unif Sch Dist    Los Angeles              f             f
# 3      New York City Dept Of Ed       Brooklyn              f             t
# 4   Central Islip Union Free SD  Central Islip              f             f
#
#   teacher_prefix     school_county primary_focus_subject  \
# 0           Mrs.              Cook           Mathematics
# 1           Mrs.           Ventura   Civics & Government
# 2            Ms.       Los Angeles              Literacy
# 3            Ms.  Kings (Brooklyn)              Literacy
# 4           Mrs.           Suffolk              Literacy
#
#   secondary_focus_subject resource_type    poverty_level    grade_level  \
# 0             Visual Arts      Supplies  highest poverty  Grades PreK-2
# 1    Literature & Writing         Books  highest poverty     Grades 3-5
# 2         Social Sciences    Technology     high poverty     Grades 3-5
# 3                     NaN         Books     high poverty  Grades PreK-2
# 4    Literature & Writing    Technology     high poverty  Grades PreK-2
#
#    total_price_including_optional_support  students_reached  \
# 0                             1498.609985              31.0
# 1                              282.470001              28.0
# 2                             1012.380005              56.0
# 3                              175.330002              23.0
# 4                             3591.110107             150.0
#
#   eligible_double_your_impact_match date_posted school_metro fund_60day
# 0                                 f  2013-04-14        urban          1
# 1                                 t  2012-04-07        urban          1
# 2                                 f  2012-01-30        urban          0
# 3                                 f  2012-10-11        urban          1
# 4                                 f  2013-01-08     suburban          0

# %%
# Checking underfunded projects against poverty
df_m['poverty_level'].describe()
sns.catplot(x="fund_60day", y="total_price_including_optional_support", data=df_m)

# %% [markdown]
# # VI: Running Model
# ## VI.A: TestGrid -> Round I

# %%
# A.) Determine start and end date
start_time_date = df_m['date_posted'].min()
end_time_date = df_m['date_posted'].max()

# B.) Obtain classifier name and grid size
clfs, test_grid=cl.define_clfs_params(grid_size='test')

# C.) Specify Classifiers to run
models_to_run=['RF', 'BG', 'AB', 'LR', 'GB', 'DT', 'KNN']

# D.) Create labels/features and Split
time_var='date_posted'
pred_var='fund_60day'

train_start='2012-01-01'
train_end='2012-06-30'

test_start='2012-07-01'
test_end='2012-12-31'

# %% [markdown]
# ### Simulation on Test Grid: Use basic guidance for trends primarily KNN
#
# Model Selection: Running through, Linear Classifier, Tree(DT), Bagging (BG and ensemble bag RF), Boosting (Ada, GB) & Space Paritioning (chose KNN over SVM)

# %%
# Running on test_grid only to have models completed in reasonable amount of time
results_base = cl.clf_wrapper(df_m, start_time_date, end_time_date, prediction_windows, time_var,pred_var, \
                models_to_run, clfs, test_grid, missing_var, dum_var, bin_var, norm_var, maj_cities, observation_period)
results_base.to_csv("model_summary/Fund60_ClfSim_testgrd.csv")

# # One simulation run with inlcuding, running others without it
# Out:
# training date range: 2012-01-01 00:00:00 2012-06-30 00:00:00
# testing date range:
#  2012-08-29 00:00:00 2013-02-27 00:00:00
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                  8524  0.323050
# school_metro                             2643  0.100167
# school_district                            33  0.001251
# students_reached                            4  0.000152
# resource_type                               2  0.000076
# primary_focus_subject                       2  0.000076
# grade_level                                 1  0.000038
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.      3705
# Mrs.    12625
# Ms.     10056
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
# (26386, 7095)
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 11110  0.331098
# school_metro                             4042  0.120459
# school_district                            66  0.001967
# students_reached                           22  0.000656
# resource_type                               5  0.000149
# primary_focus_subject                       4  0.000119
# grade_level                                 2  0.000060
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.      4542
# Mrs.    15985
# Ms.     13028
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
# (33555, 8123)
# common_cols 5118
# RF
# ---1
# ---2
# ---3
# 3.642868995666504 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ---1
# ---2
# ---3
# 3.2062931060791016 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ---1
# ---2
# ---3
# 3.157411813735962 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ---1
# ---2
# ---3
# 3.4146201610565186 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# BG
# ---1
# ---2
# ---3
# 2.8356082439422607 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 4.172860145568848 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.1, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 3.0695998668670654 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.5, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 4.012602090835571 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 4.9704320430755615 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 16.12903094291687 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.1, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 5.888845920562744 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 18.194175004959106 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# AB
# ---1
# ---2
# ---3
# 3.5165090560913086 :Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1, random_state=None)
# ---1
# ---2
# ---3
# 5.814414024353027 :Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=5, random_state=None)
# LR
# ---1
# ---2
# ---3
# 6.62836480140686 :Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 5.9882659912109375 :Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 8.693262100219727 :Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 6.390044927597046 :Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 9.355244159698486 :Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 7.4421162605285645 :Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# GB
# ---1
# ---2
# ---3
# 21.534187078475952 :Time for running GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1, presort='auto',
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# DT
# ---1
# ---2
# ---3
# 4.291112899780273 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 3.86547589302063 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 3.4425508975982666 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 5.943945407867432 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 4.910691022872925 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 5.180917978286743 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 6.67903995513916 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 6.131948947906494 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 6.595431089401245 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.7975568771362305 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.784011125564575 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.734126091003418 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 3.4700801372528076 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 3.4628748893737793 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 3.395815849304199 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 5.033995866775513 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 5.003987789154053 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 4.982401132583618 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 6.29009485244751 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 6.214262962341309 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 6.2213099002838135 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.714414119720459 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.954187870025635 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.677237033843994 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# KNN
# ---1
# ---2
# ---3
# 2459.616567134857 :Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=20, p=2,
#            weights='uniform')
# ---1
# ---2
# ---3
# 2671.446534872055 :Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=25, p=2,
#            weights='uniform')
#
#
#
# Check for Skewed Classes
# training date range: 2012-01-01 00:00:00 2012-12-30 00:00:00
# testing date range:
#  2013-02-28 00:00:00 2013-08-27 00:00:00
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 19564  0.330713
# school_metro                             6608  0.111703
# school_district                            92  0.001555
# students_reached                            4  0.000068
# resource_type                               2  0.000034
# primary_focus_subject                       2  0.000034
# grade_level                                 1  0.000017
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.      7969
# Mrs.    28191
# Ms.     22997
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
# (59157, 10092)
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                  7749  0.321442
# school_metro                             3235  0.134193
# students_reached                           33  0.001369
# school_district                            20  0.000830
# resource_type                              10  0.000415
# primary_focus_subject                       9  0.000373
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# grade_level                                 0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Dr.         2
# Mr.      2699
# Mrs.    11956
# Ms.      9450
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
# (24107, 8140)
# common_cols 6288
# RF
# ---1
# ---2
# ---3
# 7.679728031158447 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ---1
# ---2
# ---3
# 7.37625789642334 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ---1
# ---2
# ---3
# 6.236629009246826 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ---1
# ---2
# ---3
# 6.497726917266846 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# BG
# ---1
# ---2
# ---3
# 5.3410420417785645 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 10.65254807472229 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.1, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 5.668552875518799 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.5, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 11.349669933319092 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 11.44121503829956 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 47.13897490501404 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.1, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 17.16435480117798 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 85.80659317970276 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# AB
# ---1
# ---2
# ---3
# 7.493825912475586 :Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1, random_state=None)
# ---1
# ---2
# ---3
# 14.741329908370972 :Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=5, random_state=None)
# LR
# ---1
# ---2
# ---3
# 16.783593893051147 :Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 15.438922882080078 :Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 21.40216612815857 :Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 16.205118894577026 :Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 22.821229934692383 :Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 21.194865226745605 :Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# GB
# ---1
# ---2
# ---3
# 50.788296937942505 :Time for running GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1, presort='auto',
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# DT
# ---1
# ---2
# ---3
# 9.569152116775513 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.735447883605957 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.639594078063965 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 15.760674953460693 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 14.702365159988403 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 15.88853907585144 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 21.652446031570435 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 20.475584983825684 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 20.446978092193604 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 27.946682691574097 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 27.87962818145752 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 27.99232006072998 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.2343831062316895 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.050544261932373 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 7.067255735397339 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 14.227749109268188 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 14.452967882156372 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 13.999558925628662 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 20.508395195007324 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 19.959589958190918 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 20.77964997291565 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 27.921582221984863 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 27.827273845672607 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 27.70636510848999 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# KNN
# ---1
# ---2
# ---3
# 4842.361740112305 :Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=20, p=2,
#            weights='uniform')
# ---1
# ---2
# ---3
# 3941.2472512722015 :Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=25, p=2,
#            weights='uniform')
#
#
#
# Check for Skewed Classes
# training date range: 2012-01-01 00:00:00 2013-06-30 00:00:00
# testing date range:
#  2013-08-29 00:00:00 2014-02-27 00:00:00
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 26340  0.325954
# school_metro                             9412  0.116472
# school_district                           118  0.001460
# students_reached                           59  0.000730
# resource_type                              17  0.000210
# primary_focus_subject                      15  0.000186
# grade_level                                 3  0.000037
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.     10567
# Mrs.    38947
# Ms.     31295
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
# (80809, 11498)
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 10534  0.316803
# school_metro                             4284  0.128838
# school_district                            41  0.001233
# eligible_double_your_impact_match           0  0.000000
# students_reached                            0  0.000000
# total_price_including_optional_support      0  0.000000
# grade_level                                 0  0.000000
# poverty_level                               0  0.000000
# resource_type                               0  0.000000
# primary_focus_subject                       0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.      4523
# Mrs.    15899
# Ms.     12829
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
# (33251, 8430)
# common_cols 6903
# RF
# ---1
# ---2
# ---3
# 13.010080099105835 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ---1
# ---2
# ---3
# 7.710059881210327 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ---1
# ---2
# ---3
# 6.7913289070129395 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ---1
# ---2
# ---3
# 7.192561149597168 :Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# BG
# ---1
# ---2
# ---3
# 6.198709011077881 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 12.841928958892822 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
# ...
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 17.674421787261963 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 58.63756990432739 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.1, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 18.089030981063843 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 67.31146764755249 :Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)
# AB
# ---1
# ---2
# ---3
# 10.215240001678467 :Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1, random_state=None)
# ---1
# ---2
# ---3
# 18.33962082862854 :Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=5, random_state=None)
# LR
# ---1
# ---2
# ---3
# 20.044660091400146 :Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 18.666876077651978 :Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 25.48327898979187 :Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 19.54583501815796 :Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 26.268556118011475 :Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# ---1
# ---2
# ---3
# 22.454248189926147 :Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# GB
# ---1
# ---2
# ---3
# 58.27722191810608 :Time for running GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1, presort='auto',
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# DT
# ---1
# ---2
# ---3
# 9.608262777328491 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 9.675389051437378 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 9.662148237228394 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 16.553514003753662 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 16.697915077209473 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 16.677356004714966 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 21.839670658111572 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 22.180850982666016 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 21.800789833068848 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 28.6038601398468 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 29.17499327659607 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 34.49681091308594 :Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 9.992169857025146 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 9.77618408203125 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 9.744099140167236 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 16.5534348487854 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 16.682834148406982 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 16.561811923980713 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 21.998863220214844 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 21.887587070465088 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 21.88933300971985 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 28.748636960983276 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 28.952471017837524 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# ---1
# ---2
# ---3
# 28.86575412750244 :Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# KNN
# ---1
# ---2
# ---3
# 14358.98595404625 :Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=20, p=2,
#            weights='uniform')
# ---1
# ---2
# ---3
# 15294.196025133133 :Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=25, p=2,
#            weights='uniform')
#
#
#
# Check for Skewed Classes

# %% [markdown]
# ## Analysing TestGrid Results

# %%
results_base.describe()
# Out:
#          baseline     auc-roc      a_at_5     a_at_20     a_at_50     f1_at_5  \
# count  188.000000  188.000000  188.000000  188.000000  188.000000  188.000000
# mean     0.712403    0.616094    0.324739    0.415529    0.614701    0.114304
# std      0.021783    0.040797    0.022336    0.036987    0.057679    0.013388
# min      0.681088    0.499128    0.276561    0.269587    0.523653    0.070979
# 25%      0.699484    0.600580    0.308337    0.391397    0.581483    0.106985
# 50%      0.714421    0.623555    0.323261    0.420656    0.598779    0.114954
# 75%      0.727340    0.645633    0.344224    0.439851    0.630331    0.124268
# max      0.739681    0.670338    0.368897    0.518895    0.818891    0.136745
#
#          f1_at_20    f1_at_50      p_at_1      p_at_5     p_at_10     p_at_20  \
# count  188.000000  188.000000  188.000000  188.000000  188.000000  188.000000
# mean     0.359570    0.682226    0.891766    0.871540    0.845550    0.819841
# std      0.034573    0.047354    0.109268    0.102892    0.084122    0.077817
# min      0.212953    0.608598    0.544503    0.536424    0.622355    0.482140
# 25%      0.342280    0.653949    0.825620    0.815100    0.796266    0.788248
# 50%      0.363411    0.669525    0.897522    0.877013    0.857434    0.825865
# 75%      0.381745    0.694390    1.000000    0.948857    0.904347    0.869082
# max      0.453955    0.846656    1.000000    1.000000    1.000000    1.000000
#
#           p_at_50      r_at_1      r_at_5     r_at_10     r_at_20     r_at_50
# count  188.000000  188.000000  188.000000  188.000000  188.000000  188.000000
# mean     0.827113    0.012504    0.061167    0.118686    0.230332    0.580757
# std      0.058447    0.001510    0.007177    0.011340    0.022469    0.041407
# min      0.718825    0.007704    0.038004    0.084126    0.136655    0.516342
# 25%      0.787341    0.011671    0.057168    0.111724    0.218668    0.557638
# 50%      0.817099    0.012772    0.061599    0.119802    0.233332    0.569538
# 75%      0.852953    0.013521    0.066495    0.127288    0.245732    0.593159
# max      1.000000    0.014678    0.073391    0.146781    0.293623    0.734089

# %% [markdown]
# ### AUC-ROC Performance across models: compare with baseline

# %%
# Spread of Results: Model Performance by Classifier used
g = sns.FacetGrid(results_base, col='model_type', palette="Set1")
g = (g.map(sns.kdeplot, 'auc-roc', shade=True, color='tab:red'))
sns.set(rc={'figure.figsize':(20,12)})

# %% [markdown]
# The models with minimal parameters perform better on average than random prediction

# %% [markdown]
# ### Precision at 5 performance across models

# %%
# Spread of Results: Precision at 5% Performance by Classifier used
sns.catplot(x="p_at_5", y="model_type", data=results_base)

# %% [markdown]
# ### Compare Precision curve across models

# %%
cl.compare_metrics(results_base, pivot_by='model_type', metric='precision')

# %% [markdown]
# Tesgrid is greatly restricted in parameter ranges and therefore it so higher values can considered sub-optimised fitting

# %% [markdown]
# ## <span style="color:red"> Pit Stop:  Models to select for tuning in round II </span>
#
# - LR and KNN: low precision as well as timetaking
#     - Call for round II: Drop LR and KNN
# - Narrow spead in GBM could be indicative of overfitting with limited paramters: this gives guidance that one must think overfitting control
#     - Call for round II: preferrence of AB over GB
#     - Increase shrinkage, learning rate as it already seems to overfit
# - RF lesser noisier than DT
#     - Call for round II: drop DT use RF
# - Judgement: try both bagging and boosted ensemble
#
# NOTE:
# - for RF: max_features, min_samples_split not significant to change
# - Selectbestk and GridsearchCv: automate human judgement {not recommended}

# %% [markdown]
# ## VI.B: tuning (ExpandGrid) -> Round II
#
# ### Pruning trees: expand grid size to
# Bagging
# - induce more randomness in bagging
# - more bootsrapped trees and variable shuffling for splits
#
# Boosting
# - avoid overfitting
# - restricting observations range in nodes
#
#
# Explore deeper into parameters than wider into models

# %%
# B.) Obtain classifier name and grid size
clfs, grid=cl.define_clfs_params(grid_size='small')

# C.) Specify Classifiers to run
models_to_run=['RF','AB','GB']

# %%
# Running on expanded grid 
results_expgrd = cl.clf_wrapper(df_m, start_time_date, end_time_date, prediction_windows, time_var,pred_var, \
                models_to_run, clfs, grid, missing_var, dum_var, bin_var, norm_var, maj_cities, observation_period)
# results_expgrd.to_csv("model_summary/Fund60_ClfSim_expanded_grd.csv")
# Out:
# training date range: 2012-01-01 00:00:00 2012-06-30 00:00:00
# testing date range:
#  2012-08-29 00:00:00 2013-02-27 00:00:00
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                  8524  0.323050
# school_metro                             2643  0.100167
# school_district                            33  0.001251
# students_reached                            4  0.000152
# resource_type                               2  0.000076
# primary_focus_subject                       2  0.000076
# grade_level                                 1  0.000038
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.      3705
# Mrs.    12625
# Ms.     10056
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 11110  0.331098
# school_metro                             4042  0.120459
# school_district                            66  0.001967
# students_reached                           22  0.000656
# resource_type                               5  0.000149
# primary_focus_subject                       4  0.000119
# grade_level                                 2  0.000060
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.      4542
# Mrs.    15985
# Ms.     13028
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
# RF
# ---model fitting--
#
# Time = 3.7027618885040283 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 3.403832197189331 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 7.481462001800537 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 4.0230872631073 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 5.92873215675354 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 12.566239833831787 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 4.4458839893341064 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 7.1093010902404785 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 26.506914854049683 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 8.680592060089111 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 18.28160834312439 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 58.34896779060364 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# AB
# ---model fitting--
#
# Time = 10.751146078109741 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=10, random_state=None)
#
# ---model fitting--
#
# Time = 37.9680290222168 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None)
#
# ---model fitting--
#
# Time = 75.40605592727661 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=100, random_state=None)
#
# ---model fitting--
#
# Time = 340.4736762046814 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=500, random_state=None)
#
# ---model fitting--
#
# Time = 638.0367207527161 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1000, random_state=None)
# ---model fitting--
#
# Time = 8.97300410270691 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=10, random_state=None)
#
# ---model fitting--
#
# Time = 32.21032905578613 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None)
#
# ---model fitting--
#
# Time = 61.758301973342896 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=100, random_state=None)
#
# ---model fitting--
#
# Time = 326.8034989833832 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=500, random_state=None)
#
# ---model fitting--
#
# Time = 636.2196252346039 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1000, random_state=None)
#
# GB
# ---model fitting--
#
# Time = 132.5851240158081 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 750.2567889690399 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 202.7152557373047 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 1422.8736598491669 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 97.8292727470398 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 594.711131811142 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 172.31016492843628 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 1211.3120782375336 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
#
#
#
# Check for Skewed Classes
# training date range: 2012-01-01 00:00:00 2012-12-30 00:00:00
# testing date range:
#  2013-02-28 00:00:00 2013-08-27 00:00:00
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 19564  0.330713
# school_metro                             6608  0.111703
# school_district                            92  0.001555
# students_reached                            4  0.000068
# resource_type                               2  0.000034
# primary_focus_subject                       2  0.000034
# grade_level                                 1  0.000017
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.      7969
# Mrs.    28191
# Ms.     22997
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                  7749  0.321442
# school_metro                             3235  0.134193
# students_reached                           33  0.001369
# school_district                            20  0.000830
# resource_type                              10  0.000415
# primary_focus_subject                       9  0.000373
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# grade_level                                 0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Dr.         2
# Mr.      2699
# Mrs.    11956
# Ms.      9450
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
# RF
# ---model fitting--
#
# Time = 7.734236001968384 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 6.082431077957153 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 9.482458114624023 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 5.3321850299835205 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 8.54754900932312 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 20.857650995254517 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 5.789692163467407 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 11.963778018951416 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 41.416998863220215 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 7.108553886413574 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 23.979896068572998 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 94.79439902305603 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# AB
# ---model fitting--
#
# Time = 21.53110122680664 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=10, random_state=None)
#
# ---model fitting--
#
# Time = 88.325021982193 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None)
#
# ---model fitting--
#
# Time = 171.0136148929596 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=100, random_state=None)
#
# ---model fitting--
#
# Time = 839.504111289978 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=500, random_state=None)
#
# ---model fitting--
#
# Time = 1668.9696912765503 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1000, random_state=None)
# ---model fitting--
#
# Time = 22.470988035202026 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=10, random_state=None)
#
# ---model fitting--
#
# Time = 88.51724481582642 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None)
#
# ---model fitting--
#
# Time = 171.26331996917725 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=100, random_state=None)
#
# ---model fitting--
#
# Time = 835.1518080234528 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=500, random_state=None)
#
# ---model fitting--
#
# Time = 1674.7211759090424 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1000, random_state=None)
#
# GB
# ---model fitting--
#
# Time = 410.9224388599396 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 2321.880751848221 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 716.3308370113373 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 4654.871314048767 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 312.64299631118774 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 1684.3275229930878 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 578.8534030914307 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 3360.827800989151 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
#
#
#
# Check for Skewed Classes
# training date range: 2012-01-01 00:00:00 2013-06-30 00:00:00
# testing date range:
#  2013-08-29 00:00:00 2014-02-27 00:00:00
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 26340  0.325954
# school_metro                             9412  0.116472
# school_district                           118  0.001460
# students_reached                           59  0.000730
# resource_type                              17  0.000210
# primary_focus_subject                      15  0.000186
# grade_level                                 3  0.000037
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.     10567
# Mrs.    38947
# Ms.     31295
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 10534  0.316803
# school_metro                             4284  0.128838
# school_district                            41  0.001233
# eligible_double_your_impact_match           0  0.000000
# students_reached                            0  0.000000
# total_price_including_optional_support      0  0.000000
# grade_level                                 0  0.000000
# poverty_level                               0  0.000000
# resource_type                               0  0.000000
# primary_focus_subject                       0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.      4523
# Mrs.    15899
# Ms.     12829
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
# RF
# ---model fitting--
#
# Time = 9.062985181808472 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 9.00449800491333 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 13.103957176208496 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 7.888182163238525 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 11.615262269973755 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 29.40296506881714 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 8.240744829177856 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 17.592840909957886 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 60.45964074134827 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 10.621469020843506 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 33.39292287826538 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 134.26307463645935 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# AB
# ---model fitting--
#
# Time = 32.14436078071594 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=10, random_state=None)
#
# ---model fitting--
#
# Time = 131.3650608062744 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None)
#
# ---model fitting--
#
# Time = 256.2736451625824 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=100, random_state=None)
#
# ---model fitting--
#
# Time = 1283.3786869049072 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=500, random_state=None)
#
# ---model fitting--
#
# Time = 2503.116506099701 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1000, random_state=None)
# ---model fitting--
#
# Time = 33.30734992027283 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=10, random_state=None)
#
# ---model fitting--
#
# Time = 132.32190489768982 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None)
#
# ---model fitting--
#
# Time = 316.25650095939636 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=100, random_state=None)
#
# ---model fitting--
#
# Time = 1671.3037061691284 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=500, random_state=None)
#
# ---model fitting--
#
# Time = 2675.1599040031433 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1000, random_state=None)
#
# GB
# ---model fitting--
#
# Time = 690.3291301727295 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
# ...
# primary_focus_subject                       9  0.000157
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# grade_level                                 0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Dr.         2
# Mr.      7234
# Mrs.    27854
# Ms.     22301
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
# RF
# ---model fitting--
#
# Time = 12.250946998596191 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 12.432197332382202 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 16.773236989974976 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 11.154560089111328 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 14.95753002166748 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 34.001177072525024 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 11.55305004119873 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 20.74237608909607 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 51.287153244018555 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 14.625099897384644 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 36.40960907936096 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# ---model fitting--
#
# Time = 135.93220472335815 for running:
#  RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
#
# AB
# ---model fitting--
#
# Time = 38.20659303665161 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=10, random_state=None)
#
# ---model fitting--
#
# Time = 118.45096206665039 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None)
#
# ---model fitting--
#
# Time = 238.93537402153015 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=100, random_state=None)
#
# ---model fitting--
#
# Time = 1137.8344390392303 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=500, random_state=None)
#
# ---model fitting--
#
# Time = 2254.6951739788055 for running:
#  AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1000, random_state=None)
# ---model fitting--
#
# Time = 29.63529896736145 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=10, random_state=None)
#
# ---model fitting--
#
# Time = 112.04621005058289 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None)
#
# ---model fitting--
#
# Time = 243.05803275108337 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=100, random_state=None)
#
# ---model fitting--
#
# Time = 1066.0710439682007 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=500, random_state=None)
#
# ---model fitting--
#
# Time = 2351.387321949005 for running:
#  AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1000, random_state=None)
#
# GB
# ---model fitting--
#
# Time = 456.2267758846283 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 2789.6112339496613 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 884.7432582378387 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 5883.0142567157745 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 421.1757311820984 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 2300.2466807365417 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=10,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 683.7419121265411 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
# ---model fitting--
#
# Time = 4290.1732342243195 for running:
#  GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
#
#
#
#
# Check for Skewed Classes

# %%
results_expgrd.describe()
# Out:
#          baseline     auc-roc      a_at_5     a_at_20     a_at_50     f1_at_5  \
# count  120.000000  120.000000  120.000000  120.000000  120.000000  120.000000
# mean     0.712403    0.653417    0.328648    0.435920    0.595632    0.119461
# std      0.021816    0.031696    0.021238    0.026082    0.017427    0.006667
# min      0.681088    0.524408    0.288958    0.282608    0.526250    0.098835
# 25%      0.699484    0.648870    0.309673    0.421107    0.588675    0.117438
# 50%      0.714421    0.659991    0.323178    0.442603    0.599835    0.121380
# 75%      0.727340    0.671016    0.340909    0.452354    0.606719    0.123889
# max      0.739681    0.699561    0.361845    0.467375    0.626416    0.127099
#
#          f1_at_20    f1_at_50      p_at_1      p_at_5     p_at_10     p_at_20  \
# count  120.000000  120.000000  120.000000  120.000000  120.000000  120.000000
# mean     0.381853    0.666420    0.922795    0.910638    0.900304    0.870819
# std      0.021717    0.014269    0.053514    0.050154    0.039986    0.050539
# min      0.222946    0.607044    0.741710    0.735270    0.763900    0.514586
# 25%      0.378356    0.661418    0.889552    0.893972    0.884049    0.858950
# 50%      0.387357    0.668508    0.936087    0.923144    0.908521    0.883467
# 75%      0.393096    0.675138    0.964408    0.948501    0.928559    0.900791
# max      0.398788    0.689696    1.000000    0.966907    0.959699    0.920451
#
#           p_at_50      r_at_1      r_at_5     r_at_10     r_at_20     r_at_50
# count  120.000000  120.000000  120.000000  120.000000  120.000000  120.000000
# mean     0.808045    0.012944    0.063928    0.126415    0.244592    0.567255
# std      0.024628    0.000773    0.003605    0.005508    0.014258    0.012800
# min      0.731870    0.010495    0.052919    0.105399    0.142299    0.518251
# 25%      0.791363    0.012588    0.062747    0.123995    0.242020    0.561191
# 50%      0.811893    0.013183    0.065042    0.128084    0.248839    0.571375
# 75%      0.829038    0.013479    0.066334    0.130489    0.252707    0.575142
# max      0.843669    0.014130    0.068214    0.133504    0.255801    0.592789

# %%
# Spread of Results: Model Performance by Classifier used
g = sns.FacetGrid(results_expgrd, col='model_type', palette="Set1")
g = (g.map(sns.kdeplot, 'auc-roc', shade=True, color='tab:red'))
sns.set(rc={'figure.figsize':(20,12)})

# %% [markdown]
# ### Performance spread of the model might be particularly useful for overall fitting process across classifier types

# %%
# Overview of Model Performance by AUC
sns.catplot(x="p_at_5", y="model_type", data=results_expgrd)

# %%
cl.compare_metrics(results_expgrd, pivot_by='model_type', metric='precision')

# %%
cl.compare_metrics(results_expgrd, pivot_by='model_type', metric='recall')

# %% [markdown]
# # VII: Choosing best model

# %% [markdown]
# ### Commentary
# - Based on the capacity constraint of reaching out to 5% within 60 days period, precision is most useful metric to consider.
#     - In other words, the model focuses on precisely identified the actually underfunded projects
# - User-defined function for selecting best model based on specified metric {helpful to test across different time horizons}

# %%
# Evaluation Metric
stats='p_at_5' # selected
# stats='f1_at_50'# stats='auc-roc'# stats='p_at_50' 

# Window
train_date=(('2012-01-01 00:00:00'), ('2012-12-30 00:00:00')) # 1 year
test_date=(('2012-12-31 00:00:00'), ('2013-06-29 00:00:00'))  # 6 months

# Extract the best model
best_fit, mod_stat = cl.best_model(model_data=df_m, model_results=results_expgrd, time_var=time_var, 
                                   tr_date=train_date, te_date=test_date, pred_var=pred_var, m_var=missing_var, 
                                   c_var=cat_var, b_var=bin_var, n_var=norm_var, mj_cities=maj_cities,
                                   eval_stat=stats, window='best')
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
# Class Skewness
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 26340  0.325954
# school_metro                             9412  0.116472
# school_district                           118  0.001460
# students_reached                           59  0.000730
# resource_type                              17  0.000210
# primary_focus_subject                      15  0.000186
# grade_level                                 3  0.000037
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.     10567
# Mrs.    38947
# Ms.     31295
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 10534  0.316803
# school_metro                             4284  0.128838
# school_district                            41  0.001233
# eligible_double_your_impact_match           0  0.000000
# students_reached                            0  0.000000
# total_price_including_optional_support      0  0.000000
# grade_level                                 0  0.000000
# poverty_level                               0  0.000000
# resource_type                               0  0.000000
# primary_focus_subject                       0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.      4523
# Mrs.    15899
# Ms.     12829
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-132-b52798ac7958> in <module>()
#      11                                    tr_date=train_date, te_date=test_date, pred_var=pred_var, m_var=missing_var,
#      12                                    c_var=cat_var, b_var=bin_var, n_var=norm_var, mj_cities=maj_cities,
# ---> 13                                    eval_stat=stats, window='best')
#
# ~/Parth_Repos/Machine-Learning-for-Public-Polcy/Improving_Pipeline_II/MLClassifier_helper.py in best_model(model_data, model_results, time_var, pred_var, tr_date, te_date, m_var, c_var, b_var, n_var, mj_cities, eval_stat, window)
#     482     # Fit model
#     483     best = best_mod.loc[bi].clf
# --> 484     best_fit = best.fit(bx_train, by_train)
#     485
#     486     # Generate predictions
#
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in fit(self, X, y, sample_weight, monitor)
#    1032         # fit the boosting stages
#    1033         n_stages = self._fit_stages(X, y, y_pred, sample_weight, random_state,
# -> 1034                                     begin_at_stage, monitor, X_idx_sorted)
#    1035         # change shape of arrays after fit (early-stopping or additional ests)
#    1036         if n_stages != self.estimators_.shape[0]:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in _fit_stages(self, X, y, y_pred, sample_weight, random_state, begin_at_stage, monitor, X_idx_sorted)
#    1087             y_pred = self._fit_stage(i, X, y, y_pred, sample_weight,
#    1088                                      sample_mask, random_state, X_idx_sorted,
# -> 1089                                      X_csc, X_csr)
#    1090
#    1091             # track deviance (= loss)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in _fit_stage(self, i, X, y, y_pred, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#     786             else:
#     787                 tree.fit(X, residual, sample_weight=sample_weight,
# --> 788                          check_input=False, X_idx_sorted=X_idx_sorted)
#     789
#     790             # update tree leaves
#
# /anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1122             sample_weight=sample_weight,
#    1123             check_input=check_input,
# -> 1124             X_idx_sorted=X_idx_sorted)
#    1125         return self
#    1126
#
# /anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %% [markdown]
# # VII B: Best model robustness across different windows
#
# - Checking class imbalance first so PR make more sense
# - Leverage user defined function to test

# %%
# Robustness across windows
stats='p_at_5' # selected

# Robustness across windows I
train_date=(('2012-01-01 00:00:00'), ('2012-12-30 00:00:00')) # 1 year
test_date=(('2012-12-31 00:00:00'), ('2013-06-29 00:00:00'))  # 6 months

# Robustness across windows II
# train_date=(('2012-01-01 00:00:00'), ('2013-06-30 00:00:00')) # 1.5 years
# test_date=(('2013-07-01 00:00:00'), ('2013-12-31 00:00:00'))  # 6 months

# Robustness across windows III
# train_date=(('2012-01-01 00:00:00'), ('2012-12-31 00:00:00')) # 2 years
# test_date=(('2013-01-01 00:00:00'), ('2013-12-31 00:00:00'))  # 1year

# Extract the best model
by_pred_probs = cl.best_model(model_data=df_m, model_results=results_expgrd, time_var=time_var, 
                               tr_date=train_date, te_date=test_date, pred_var=pred_var, m_var=missing_var, 
                               c_var=cat_var, b_var=bin_var, n_var=norm_var, mj_cities=maj_cities,eval_stat=stats)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.5, loss='deviance', max_depth=20,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=500,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=0.8, verbose=0,
#               warm_start=False)
# Class Skewness
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 26340  0.325954
# school_metro                             9412  0.116472
# school_district                           118  0.001460
# students_reached                           59  0.000730
# resource_type                              17  0.000210
# primary_focus_subject                      15  0.000186
# grade_level                                 3  0.000037
# eligible_double_your_impact_match           0  0.000000
# total_price_including_optional_support      0  0.000000
# poverty_level                               0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.     10567
# Mrs.    38947
# Ms.     31295
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables
#
#
#  Feature engineering module
# Treating Missing Values
#                                         Total   Percent
# secondary_focus_subject                 10534  0.316803
# school_metro                             4284  0.128838
# school_district                            41  0.001233
# eligible_double_your_impact_match           0  0.000000
# students_reached                            0  0.000000
# total_price_including_optional_support      0  0.000000
# grade_level                                 0  0.000000
# poverty_level                               0  0.000000
# resource_type                               0  0.000000
# primary_focus_subject                       0  0.000000
# Major cities dummy
# Gender dummy
# teacher_prefix
# Mr.      4523
# Mrs.    15899
# Ms.     12829
# dtype: int64
# Creating Dummy labels for categoricals
# Creating Binary labels
# Normalise Skewed Variables

# %% [markdown]
# ## <span style="color:red"> Pit Stop:  Best Model Selection </span>
#
# - Assess model via AUC-ROC spread across models
# - Check precision ranges
# - Pruning trees via restricting observation in nodes
# - Gradient boosting shows promising signs however vulnerable to overfitting, so tested with stricter controls on parameters
# - Gradient boosted model with 100 estimators, learning rate: 0.5 , max depth: 20, min sample split: 100 & subsample 0.8
# 	- learning rate: 0.5 not kept much lower to avoid mimicking the distribution exactly
# 	- max depth: 20 and min sample split: 100 both again trying to ensure that fit is close but not exact to work with different test datasets
# 	- subsample: 0.8, considering < 1 leads to stochastic gradient boosting, this was done to induce more randomness
# - Checked best model & fit parameters across for different intertemporal horizons

# %% [markdown]
# # VIII Model Result & Summary
#
# The objective of the present analysis was to prioritize which 5% of school projects should a donor prioritize their intervention on, to help with aid and assistance? Based on likely capacity constraint faced by a prospective donor (Donor’s Choose) reaching out to 5% within 60 days period, precision is most useful metric to consider. In other words, the model focuses on precisely identified the actually underfunded projects. Gradient boosted model with 100 estimators, learning rate: 0.5, max depth: 20, min sample split: 500 & subsample 0.8 performs best in this regard. The model gives sturdier prediction when trained on 1-year data and tested on 6 months window.
