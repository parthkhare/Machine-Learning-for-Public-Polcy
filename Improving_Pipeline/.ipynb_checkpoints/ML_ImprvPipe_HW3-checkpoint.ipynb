# %% [markdown]
# # <span style="color:blue"> Immproving ML Pipeline: Assignment III </span>

# %% [markdown]
# ## Libraries & Helper Function

# %%
import pandas as pd
import seaborn as sns
import warnings
import numpy as np
import scipy as sp
import graphviz 
import matplotlib.pyplot as plt

from IPython.display import display
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score as accuracy
from sklearn.preprocessing import normalize, scale
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier, OrthogonalMatchingPursuit, RandomizedLogisticRegression
from sklearn.neighbors.nearest_centroid import NearestCentroid
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

# Helper Function
import MLPreprocess_helper as mh
import MLClassifier_helper as cl

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
# Import Data
filepath = "data/projects_2012_2013.csv"
df = mh.import_data(filepath)

# %% [markdown]
# ## II A: Explore Features
#
# Bird' s eye view of how the data looks like.
# Customised by variable type
#
# Broad level data exploration on:
# - Feature Summary (describe)
# - Compartiive feature distribution (bxoplot)

# %%
# Data Exploration: Stage I
mh.explore_features(df)
# Out:
# 'Feature Summary:'
#        school_ncesid  school_latitude  school_longitude  \
# count   1.157430e+05    124976.000000     124976.000000
# mean    2.448448e+11        36.827284        -95.859299
# std     1.644728e+11         4.963669         18.392876
# min     1.000050e+10        18.249140       -171.690554
# 25%     6.344101e+10        33.872504       -117.806418
# 50%     2.200870e+11        36.617410        -90.101563
# 75%     3.704880e+11        40.676156        -80.713740
# max     6.100010e+11        65.672562        -66.628036
#
#        total_price_including_optional_support  students_reached
# count                           124976.000000     124917.000000
# mean                               654.011811         95.445760
# std                               1098.015854        163.481912
# min                                 92.000000          1.000000
# 25%                                345.810000         23.000000
# 50%                                510.500000         30.000000
# 75%                                752.960000        100.000000
# max                             164382.840000      12143.000000
# Individual Feature Distribution I: Birds Eye

# %% [markdown]
# ## II B: Explore Features (categorical)
#
# Bird' s eye view of how the data looks like.
# Broad level data exploration on:
# - Categorical Variables (histograms)

# %%
# Specify dtypes
cat_var = ['projectid','school_ncesid','teacher_acctid', 'schoolid', 'school_city', 'school_state',
       'school_metro', 'school_district', 'school_county', 'school_charter',
       'school_magnet', 'teacher_prefix', 'primary_focus_subject',
       'primary_focus_area', 'secondary_focus_subject', 'secondary_focus_area',
       'resource_type', 'poverty_level', 'grade_level','eligible_double_your_impact_match']
cont_var = ['total_price_including_optional_support', 'students_reached']
date_var = ['date_posted', 'datefullyfunded']

# Categorical Summary
print('Number of Projects:',df['projectid'].nunique())
print('Number of Schools:',df['schoolid'].nunique())
print('Number of Teachers:',df['teacher_acctid'].nunique())
print('Number of Cities:',df['school_city'].nunique())
print('Number of School Districts:',df['school_district'].nunique())

# Plot
f, axes = plt.subplots(2, 3, figsize=(14, 6))
f.subplots_adjust(hspace=0.4, wspace=0.4)
ax = sns.countplot(x="resource_type", hue="poverty_level", data=df, ax=axes[0, 0])
ax = sns.countplot(x="resource_type", hue="grade_level", data=df, ax=axes[0, 1])
ax = sns.countplot(x="resource_type", hue="school_metro", data=df, ax=axes[0, 2])
ax = sns.countplot(x="resource_type", hue="eligible_double_your_impact_match", data=df, ax=axes[1, 0])
ax = sns.countplot(x="resource_type", hue="school_charter", data=df, ax=axes[1, 1])
ax = sns.countplot(x="resource_type", hue="school_magnet", data=df, ax=axes[1, 2])
# f.suptitle('Demand of Resource Type: comparison')
plt.tight_layout()
print('Approximately 1 school district per city')
# Out:
# Number of Projects: 124976
# Number of Schools: 29947
# Number of Teachers: 77013
# Number of Cities: 5955
# Number of School Districts: 5970
# Approximately 1 school district per city

# %% [markdown]
# ## II C: Explore Features (date/time)
#
# Broad level data exploration on:
# - Donation response time
# - Total Price Including and Excludiong Optional Support

# %%
# Convert to Date
date_var = ['date_posted', 'datefullyfunded']
df = mh.trnf_dtype(df, var_list=date_var, to_type='date')
df['resp_time'] = df['datefullyfunded'] - df['date_posted']

# Plot donation completion distribution
fig, ax = plt.subplots(1, 1, figsize=(15,5))
ax = (df['resp_time'] / np.timedelta64(1, 'D')).plot.kde(color='r')
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.arange(start, end, 10))
ax.set_xlabel("Days")
ax.set_title("Donation Response time")
# Out:
# Text(0.5,1,'Donation Response time')

# %%
# Add month, year to df to dummify in features
df['month_posted'] = df['date_posted'].dt.month
df['year_posted'] = df['date_posted'].dt.year

# Total Price Including Support
sns.factorplot(x='month_posted', y ='total_price_including_optional_support', col='year_posted', data=df, kind='box' )
plt.ylim(0,2000)
plt.title('Total Price Including Optional Support by Year, Month')
# Out:
# Text(0.5,1,'Total Price Including Optional Support by Year, Month')

# %% [markdown]
# ## III: Explore Feature Interactions
#
# Explore feature interactions amongst each other. Helps in weeding verbose (highly correlated variables). Evaluated through
# - Correlation heatmap
# - Pairwsie plots for continous attributes

# %%
# Data Exploration: Pairwise
cont_var = ['total_price_including_optional_support', 'students_reached']
df = mh.trnf_dtype(df, var_list=cont_var, to_type='cont')
mh.explore_finteractions(df, cont_var)
# Out:
# Pairwise Feature Distribution: Variable Histograms
# Pairwise Feature Distribution: Pairplot

# %% [markdown]
# ## <span style="color:red"> Pit Stop: Observations from School Donors Data </span>
#
# Following quick observation may be drawn for data on 124 thousand project proposal over 2 years.
#
# - Multi-modal Dononation response time stands out
#     - particularly the drop in number of donations for around 60days
#
# - Relatively higher contribution in supplies & technology
#     - relatively higher overall donation in urban areas
#     - higher donation made in high poverty schools
#     - higher donations made in pre-K2 grades
#
# - Total pricing and students reached attributes show a near *Gamma* distribution
#     - which *supports* trying a non-parametric/Machine learning based method
#     - conventional regression frameworks (in some cases even GLMM) might be inept in accurately extracting variance in such cases
#     - pairwise correlation between them can be indicative of more the students reached more donation made
#
# - Average Monhtly Funding (with support) aorund $400-$500, without much seasonal variation.
# - Sizebale outliers, particular to the range of over $1500K in November 2013
#
# Caveat
# + *A caevat of the given process is not discerning categorical and continous variables. It is likely that the given datasets might have mispscified/unusable data types. So, it helpful to in the first stage throw in the variables alltogether and use these results to understand the nature and use of these feature for the subjective analysis, expeditiously*

# %% [markdown]
# ## IV: Variable Treatment
# ### IV A: Missing Values
#
# - View a summery of missing proportion by columns
# - Replace missing values by mean/median as specified
#     - specify mean=False for median
# Caveat
# + *Missing data can be present in different forms based on data or filte type (na, null, NA ,NaN :0/0 forms, '.'). Getting a sense of meaning of the feature & format of the file type is helpfu. E.g. Stata uses '.', R uses 'NA' *

# %%
# Treat Missing Values: 
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
print('Missing data summary')
display(missing_data.head(20))
df = mh.treat_missing(df, col='students_reached')
# Out:
# Missing data summary
#                          Total   Percent
# secondary_focus_subject  40556  0.324510
# secondary_focus_area     40556  0.324510
# school_metro             15224  0.121815
# school_ncesid             9233  0.073878
# school_district            172  0.001376
# students_reached            59  0.000472
# resource_type               17  0.000136
# primary_focus_area          15  0.000120
# primary_focus_subject       15  0.000120
# grade_level                  3  0.000024
# school_city                  0  0.000000
# school_county                0  0.000000
# school_longitude             0  0.000000
# school_latitude              0  0.000000
# schoolid                     0  0.000000
# school_state                 0  0.000000
# teacher_acctid               0  0.000000
# year_posted                  0  0.000000
# school_charter               0  0.000000
# school_magnet                0  0.000000

# %% [markdown]
# ### Missing treatment summary
# 59 missing values student_reached treated by mean replacement.
# Ideally, given the right skewed distribution mean is not recommended, but the missing % is less than 0.001% of data
# Rest missing in categorical variable. Not imputing as of now, can use hot deck or association rules if required

# %% [markdown]
# ### IV B: Outliers/Dropping variables
# No strong pairwise correlation leading to a multinollinearity like situation.There might be correlation between total price and students reached, if outliers are removed, but considering the outliers value as part of sample for now.
#
# #### Note on Outliers
# NOTE: *Treating outliers did not seem particularly useful for the data in question. Outliers in donation and students are plausible. If however required Z-scaores are a good way to examine individual feature distirbutions.*
# `from scipy import stats
# z1 = np.abs(stats.zscore(df))
# z = np.abs(stats.zscore(df_c))`
# One can further apply a threshold on the Z-value to filter our outlier.

# %% [markdown]
# ## V: Pre-processing: Generate features/predictors
#
# ### V A: Subset Model Data
# - Excluding ID variables (projectid, school_ncesid)
#     - there are 29947 schools and 77013 teachers overall
#     - that means same teachers & schools received got multiple grants
#     - can signal donation accquiring capacity
#
# - Excluding hierarchial variables 1: geographical identifiers (lat, long, state, county, city)
#     - Multiple geographical indicators indicating same geography
#     - Choosing geographical resolution
#         - Proportionate to the data density choose higher resolution (but lower than lat,long)
#         - Remove state, county,
#         - Corresponding number of cities (5955) by school district (5970)
#         - Keeping School district as it might be a better policy indicative
#
# - Excluding hierarchial variables 2: Focus Area vs Subject (remove focus_area)
#     - Checking if focus area and focus subject have 1-1 mapping
#     - No they do not
#     - Retain category with higher resolution
#
# Hierarchial variables might drain variance from each another so keeping retaining singular types
#
# NOTE: *Instead of adding transformed variables to the same data frame, the current implementation transforms into a new dataframe to reduce steps in variable name specification in model run. This acts a check-post to avoid re-running processes from start*

# %%
# Correspondence Hierarchy
# Identifying criteria for focus area vs subject 
print(df.groupby(['primary_focus_area',"primary_focus_subject"]).size())
print(df.groupby(['secondary_focus_area',"secondary_focus_subject"]).size())
# Out:
# primary_focus_area   primary_focus_subject
# Applied Learning     Character Education       2249
#                      College & Career Prep     1217
#                      Community Service          221
#                      Early Development         2618
#                      Extracurricular            480
#                      Other                     1809
#                      Parent Involvement         128
# Health & Sports      Gym & Fitness             1281
#                      Health & Wellness         1450
#                      Nutrition                  190
#                      Sports                     574
# History & Civics     Civics & Government        428
#                      Economics                  491
#                      History & Geography       2701
#                      Social Sciences           1538
# Literacy & Language  ESL                       1604
#                      Foreign Languages          898
#                      Literacy                 37408
#                      Literature & Writing     16141
# Math & Science       Applied Sciences          5825
#                      Environmental Science     4835
#                      Health & Life Science     4185
#                      Mathematics              16859
# Music & The Arts     Music                     3931
#                      Performing Arts           1682
#                      Visual Arts               5870
# Special Needs        Special Needs             8348
# dtype: int64
# secondary_focus_area  secondary_focus_subject
# Applied Learning      Character Education         2337
#                       College & Career Prep       1879
#                       Community Service            526
#                       Early Development           3599
#                       Extracurricular              832
#                       Other                       1889
#                       Parent Involvement           500
# Health & Sports       Gym & Fitness                754
#                       Health & Wellness           1582
#                       Nutrition                    270
#                       Sports                       402
# History & Civics      Civics & Government          771
#                       Economics                    456
#                       History & Geography         2918
#                       Social Sciences             2636
# Literacy & Language   ESL                         4698
#                       Foreign Languages            371
#                       Literacy                   12598
#                       Literature & Writing       12389
# Math & Science        Applied Sciences            3380
#                       Environmental Science       2997
#                       Health & Life Science       3103
#                       Mathematics                12513
# Music & The Arts      Music                       1129
#                       Performing Arts             2438
#                       Visual Arts                 2236
# Special Needs         Special Needs               5217
# dtype: int64

# %%
# Select Model Data
model_var = ['school_district','school_charter','school_magnet','teacher_prefix',
             'primary_focus_subject','secondary_focus_subject','resource_type','poverty_level', 'grade_level',
             'total_price_including_optional_support','students_reached','eligible_double_your_impact_match',
             'date_posted','datefullyfunded','resp_time','school_metro']
df_m = df[model_var]
df_m.head()
# Out:
#                      teacher_acctid                          schoolid  \
# 0  96963218e74e10c3764a5cfb153e6fea  9f3f9f2c2da7edda5648ccd10554ed8c
# 1  2a578595fe351e7fce057e048c409b18  3432ed3d4466fac2f2ead83ab354e333
# 2  26bd60377bdbffb53a644a16c5308e82  dc8dcb501c3b2bb0b10e9c6ee2cd8afd
# 3  15d900805d9d716c051c671827109f45  8bea7e8c6e4279fca6276128db89292e
# 4  400f8b82bb0143f6a40b217a517fe311  fbdefab6fe41e12c55886c610c110753
#
#                 school_district school_charter school_magnet teacher_prefix  \
# 0         Pershing Elem Network              f             f           Mrs.
# 1  Ventura Unif School District              f             f           Mrs.
# 2     Los Angeles Unif Sch Dist              f             f            Ms.
# 3      New York City Dept Of Ed              f             t            Ms.
# 4   Central Islip Union Free SD              f             f           Mrs.
#
#   primary_focus_subject secondary_focus_subject resource_type  \
# 0           Mathematics             Visual Arts      Supplies
# 1   Civics & Government    Literature & Writing         Books
# 2              Literacy         Social Sciences    Technology
# 3              Literacy                     NaN         Books
# 4              Literacy    Literature & Writing    Technology
#
#      poverty_level    grade_level  total_price_including_optional_support  \
# 0  highest poverty  Grades PreK-2                             1498.609985
# 1  highest poverty     Grades 3-5                              282.470001
# 2     high poverty     Grades 3-5                             1012.380005
# 3     high poverty  Grades PreK-2                              175.330002
# 4     high poverty  Grades PreK-2                             3591.110107
#
#    students_reached eligible_double_your_impact_match date_posted  \
# 0              31.0                                 f  2013-04-14
# 1              28.0                                 t  2012-04-07
# 2              56.0                                 f  2012-01-30
# 3              23.0                                 f  2012-10-11
# 4             150.0                                 f  2013-01-08
#
#   datefullyfunded resp_time school_metro
# 0      2013-05-02   18 days        urban
# 1      2012-04-18   11 days        urban
# 2      2012-04-15   76 days        urban
# 3      2012-12-05   55 days        urban
# 4      2013-03-25   76 days     suburban

# %% [markdown]
# ### V B: Create Dummy Variable
# Variables that should be discretize based on data context.

# %%
cat_var = ['school_district','school_metro','teacher_prefix','primary_focus_subject',
           'secondary_focus_subject','resource_type','poverty_level','grade_level']
df_m = mh.cat_dummy(df_m, cat_var)

# %% [markdown]
# ### V C: Specify Binary Variable
# Convert binary variable into 0,1

# %%
bin_var = ['eligible_double_your_impact_match','school_charter','school_magnet']
for var in bin_var:
    df_m[var] = np.where(df_m[var] == 't', 1, 0)

# %% [markdown]
# ### V D: Normalise Continuous Variable

# %%
# Scale continuous variables for interpretable information
df_m['total_price_including_optional_support'] = scale(df_m['total_price_including_optional_support'])
df_m['students_reached'] = scale(df_m['students_reached'])

# %% [markdown]
# ### V E: Create Supervised Variable

# %%
df_m['fund_60day'] = (df_m['resp_time'] > '60 days').astype('int').astype('category')
# Prepare final model database: Checkpoint 2 
df_m=df_m.drop(labels=['teacher_acctid', 'schoolid','datefullyfunded','resp_time'], axis=1)
# Out:
# Index(['school_charter', 'school_magnet',
#        'total_price_including_optional_support', 'students_reached',
#        'eligible_double_your_impact_match', 'date_posted',
#        'school_district_Abbeville Co School District',
#        'school_district_Abc Unified School District',
#        'school_district_Aberdeen School District 5',
#        'school_district_Abilene Ind School District',
#        ...
#        'poverty_level_highest poverty', 'poverty_level_low poverty',
#        'poverty_level_moderate poverty', 'poverty_level_nan',
#        'grade_level_Grades 3-5', 'grade_level_Grades 6-8',
#        'grade_level_Grades 9-12', 'grade_level_Grades PreK-2',
#        'grade_level_nan', 'fund_60day'],
#       dtype='object', length=6060)

# %% [markdown]
# Variables that still can't be utilised (N<P): 'teacher_acctid','schoolid'

# %%
df_m['poverty_level_high poverty'].describe()
sns.catplot(x="fund_60day", y="total_price_including_optional_support", data=df_m)

# %% [markdown]
# # VI: Trying all model
# ## Model types

# %%
# A.) Determine start and end date
start_time_date = df_m['date_posted'].min()
end_time_date = df_m['date_posted'].max()

# progressive train on 6 month window
prediction_windows = [6,12]

# B.) Obtain classifier name and grid size
clfs, test_grid=cl.define_clfs_params(grid_size='test')

# C.) Create labels/features and Split
time_var='date_posted'
pred_var='fund_60day'
train_start='2012-01-01'
train_end='2012-06-30'
test_start='2012-07-01'
test_end='2012-12-31'
clfs, test_grid=cl.define_clfs_params('test')

# %%
models_to_run=['RF', 'BG', 'AB', 'LR', 'GB', 'DT', 'KNN']
clfs, test_grid=cl.define_clfs_params('test')

# %%
# Running on test_grid only to have models completed in reasonable amount of time
results = cl.clf_wrapper(df_m, start_time_date, end_time_date, prediction_windows, time_var,\
                                   pred_var, models_to_run, clfs, test_grid)
# Out:
# training date range: 2012-01-01 00:00:00 2012-06-30 00:00:00
# testing date range: 2012-07-01 00:00:00 2012-12-31 00:00:00
#
# RF
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 1} : 4.56224799156189
#
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 5} : 3.865272045135498
#
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 1} : 4.082448959350586
#
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 5} : 3.657896041870117
#
# BG
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.1, 'max_samples': 0.1, 'n_estimators': 1} : 2.9150450229644775
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.1, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.1, 'max_samples': 0.1, 'n_estimators': 5} : 4.195125102996826
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.5, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.1, 'max_samples': 0.5, 'n_estimators': 1} : 3.0879743099212646
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.1, 'max_samples': 0.5, 'n_estimators': 5} : 4.207056999206543
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.5, 'max_samples': 0.1, 'n_estimators': 1} : 6.111994028091431
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.1, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.5, 'max_samples': 0.1, 'n_estimators': 5} : 19.344514846801758
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 1} : 5.9907379150390625
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 5} : 21.018030166625977
#
# AB
# Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1, random_state=None) for: {'algorithm': 'SAMME', 'n_estimators': 1} : 4.1531078815460205
#
# Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=5, random_state=None) for: {'algorithm': 'SAMME', 'n_estimators': 5} : 6.663819074630737
#
# LR
# Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 0.1, 'penalty': 'l1'} : 7.813663005828857
#
# Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 0.1, 'penalty': 'l2'} : 7.019761085510254
#
# Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 1, 'penalty': 'l1'} : 9.010454893112183
#
# Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 1, 'penalty': 'l2'} : 7.3141303062438965
#
# Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 10, 'penalty': 'l1'} : 8.984918117523193
#
# Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 10, 'penalty': 'l2'} : 9.554199934005737
#
# GB
# Time for running GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1, presort='auto',
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False) for: {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 1, 'subsample': 0.5} : 24.35496711730957
#
# DT
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 2} : 3.9678289890289307
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 5} : 4.227312803268433
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 10} : 4.128172159194946
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2} : 6.390812158584595
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 5} : 5.463359832763672
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10} : 5.675243854522705
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2} : 6.010561943054199
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 5} : 5.369602918624878
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 10} : 5.428685903549194
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2} : 6.2245869636535645
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 5} : 6.220495939254761
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10} : 6.119959115982056
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 2} : 4.23392915725708
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 5} : 3.921571969985962
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 10} : 3.9220850467681885
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2} : 4.842076063156128
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 5} : 4.738976955413818
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 10} : 4.784482955932617
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2} : 5.741055011749268
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 5} : 5.5260329246521
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 10} : 5.59707498550415
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2} : 6.2447381019592285
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 5} : 6.2009758949279785
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 10} : 6.097350120544434
#
# KNN
# Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=20, p=2,
#            weights='uniform') for: {'algorithm': 'kd_tree', 'n_neighbors': 20, 'weights': 'uniform'} : 2615.1206130981445
#
# Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=25, p=2,
#            weights='uniform') for: {'algorithm': 'kd_tree', 'n_neighbors': 25, 'weights': 'uniform'} : 2546.968603849411
#
# training date range: 2012-01-01 00:00:00 2012-12-30 00:00:00
# testing date range: 2012-12-31 00:00:00 2013-06-29 00:00:00
#
# RF
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 1} : 7.8517608642578125
#
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 5} : 4.522928714752197
#
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 1} : 4.388944864273071
#
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 5} : 4.626275062561035
#
# BG
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.1, 'max_samples': 0.1, 'n_estimators': 1} : 3.935986042022705
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.1, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.1, 'max_samples': 0.1, 'n_estimators': 5} : 7.983824014663696
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.5, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.1, 'max_samples': 0.5, 'n_estimators': 1} : 3.8794760704040527
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.1, 'max_samples': 0.5, 'n_estimators': 5} : 8.284830808639526
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.5, 'max_samples': 0.1, 'n_estimators': 1} : 13.879532098770142
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.1, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.5, 'max_samples': 0.1, 'n_estimators': 5} : 38.45057821273804
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 1} : 9.509238004684448
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 5} : 41.31245279312134
#
# AB
# Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1, random_state=None) for: {'algorithm': 'SAMME', 'n_estimators': 1} : 5.953251838684082
#
# Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=5, random_state=None) for: {'algorithm': 'SAMME', 'n_estimators': 5} : 11.692312955856323
#
# LR
# Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 0.1, 'penalty': 'l1'} : 15.351803302764893
#
# Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 0.1, 'penalty': 'l2'} : 13.380656003952026
#
# Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 1, 'penalty': 'l1'} : 19.770479202270508
#
# Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 1, 'penalty': 'l2'} : 14.30449891090393
#
# Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 10, 'penalty': 'l1'} : 17.562512159347534
#
# Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 10, 'penalty': 'l2'} : 15.629322052001953
#
# GB
# Time for running GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1, presort='auto',
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False) for: {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 1, 'subsample': 0.5} : 38.545135736465454
#
# DT
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 2} : 5.593334913253784
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 5} : 5.50458288192749
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 10} : 5.502137184143066
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2} : 9.317976713180542
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 5} : 9.065768003463745
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10} : 9.0707368850708
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2} : 11.627060174942017
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 5} : 11.862181186676025
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 10} : 11.6130530834198
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2} : 14.668784856796265
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 5} : 14.621345043182373
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10} : 14.79738712310791
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 2} : 5.521708965301514
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 5} : 5.52567195892334
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 10} : 5.518717050552368
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2} : 9.146762132644653
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 5} : 9.395108222961426
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 10} : 9.08372712135315
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2} : 11.747644901275635
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 5} : 11.70388388633728
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 10} : 11.792613983154297
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2} : 14.852555990219116
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 5} : 14.820840120315552
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 10} : 14.894581079483032
#
# KNN
# Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=20, p=2,
#            weights='uniform') for: {'algorithm': 'kd_tree', 'n_neighbors': 20, 'weights': 'uniform'} : 6011.533730983734
#
# Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=25, p=2,
#            weights='uniform') for: {'algorithm': 'kd_tree', 'n_neighbors': 25, 'weights': 'uniform'} : 4188.937036991119
#
# training date range: 2012-01-01 00:00:00 2013-06-30 00:00:00
# testing date range: 2013-07-01 00:00:00 2013-12-31 00:00:00
#
# RF
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 1} : 16.450534105300903
#
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 5} : 9.552849054336548
#
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 1} : 8.76207184791565
#
# Time for running RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False) for: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 5} : 8.805330991744995
#
# BG
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.1,
#          max_samples=0.1, n_estimators=1, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.1, 'max_samples': 0.1, 'n_estimators': 1} : 8.1422278881073
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
# ...
#
# Time for running BaggingClassifier(base_estimator=LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#          bootstrap=True, bootstrap_features=False, max_features=0.5,
#          max_samples=0.5, n_estimators=5, n_jobs=1, oob_score=False,
#          random_state=None, verbose=0, warm_start=False) for: {'max_features': 0.5, 'max_samples': 0.5, 'n_estimators': 5} : 58.42614698410034
#
# AB
# Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1, random_state=None) for: {'algorithm': 'SAMME', 'n_estimators': 1} : 12.5889573097229
#
# Time for running AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=5, random_state=None) for: {'algorithm': 'SAMME', 'n_estimators': 5} : 20.428067207336426
#
# LR
# Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 0.1, 'penalty': 'l1'} : 23.188588857650757
#
# Time for running LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 0.1, 'penalty': 'l2'} : 26.260446071624756
# Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 1, 'penalty': 'l1'} : 38.553651094436646
#
# Time for running LogisticRegression(C=1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 1, 'penalty': 'l2'} : 27.24409508705139
#
# Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 10, 'penalty': 'l1'} : 35.89909076690674
#
# Time for running LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False) for: {'C': 10, 'penalty': 'l2'} : 38.069628953933716
#
# GB
# Time for running GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=1,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1, presort='auto',
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False) for: {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 1, 'subsample': 0.5} : 79.92052602767944
#
# DT
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 2} : 18.69945502281189
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 5} : 18.66947889328003
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 1, 'min_samples_split': 10} : 13.699095964431763
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 2} : 19.06737518310547
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 5} : 21.47881817817688
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 5, 'min_samples_split': 10} : 24.81703495979309
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 2} : 22.528934955596924
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 5} : 22.90169858932495
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 10} : 21.97852325439453
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 2} : 26.6332950592041
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 5} : 30.336984157562256
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'gini', 'max_depth': 20, 'min_samples_split': 10} : 29.836811065673828
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 2} : 18.03974485397339
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 5} : 13.201935052871704
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 1, 'min_samples_split': 10} : 12.977209091186523
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2} : 16.239610195159912
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 5} : 21.204608917236328
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 10} : 20.001827001571655
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 2} : 29.701988697052002
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 5} : 27.99928331375122
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 10} : 20.98591375350952
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 2} : 30.966141939163208
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 5} : 27.668159008026123
#
# Time for running DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best') for: {'criterion': 'entropy', 'max_depth': 20, 'min_samples_split': 10} : 24.695929050445557
#
# KNN
# Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=20, p=2,
#            weights='uniform') for: {'algorithm': 'kd_tree', 'n_neighbors': 20, 'weights': 'uniform'} : 13337.201040029526
#
# Time for running KNeighborsClassifier(algorithm='kd_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=-1, n_neighbors=25, p=2,
#            weights='uniform') for: {'algorithm': 'kd_tree', 'n_neighbors': 25, 'weights': 'uniform'} : 10321.337553024292

# %%
results.to_csv("Model_Summary/Fund60_ClfSim_testgrd.csv")
results.describe()
# Out:
#          baseline     auc-roc      a_at_5     a_at_20     a_at_50     f1_at_5  \
# count  188.000000  188.000000  188.000000  188.000000  188.000000  188.000000
# mean     0.287762    0.621134    0.687781    0.624196    0.618270    0.075360
# std      0.020928    0.039942    0.025847    0.064759    0.053712    0.054740
# min      0.256928    0.500004    0.635125    0.485145    0.529128    0.000000
# 25%      0.277717    0.604109    0.670415    0.583830    0.585054    0.010580
# 50%      0.289619    0.630474    0.691170    0.646149    0.598902    0.094992
# 75%      0.299664    0.649273    0.703989    0.673990    0.623340    0.124749
# max      0.314882    0.671645    0.737986    0.699860    0.811856    0.159301
#
#          f1_at_20    f1_at_50      p_at_1      p_at_5     p_at_10     p_at_20  \
# count  188.000000  188.000000  188.000000  188.000000  188.000000  188.000000
# mean     0.229154    0.514888    0.236164    0.255366    0.270162    0.279879
# std      0.130646    0.070889    0.202405    0.187166    0.184910    0.160558
# min      0.000000    0.389604    0.000000    0.000000    0.000000    0.000000
# 25%      0.141275    0.469169    0.002268    0.033183    0.061986    0.171176
# 50%      0.280597    0.500680    0.283321    0.315356    0.344465    0.332387
# 75%      0.332882    0.531611    0.416762    0.417283    0.422832    0.392172
# max      0.380867    0.769109    0.611111    0.581331    0.531423    0.490296
#
#           p_at_50      r_at_1      r_at_5     r_at_10     r_at_20     r_at_50
# count  188.000000  188.000000  188.000000  188.000000  188.000000  188.000000
# mean     0.406031    0.008195    0.044238    0.093808    0.194417    0.705849
# std      0.059586    0.007018    0.032122    0.063961    0.110834    0.093768
# min      0.294902    0.000000    0.000000    0.000000    0.000000    0.551145
# 25%      0.369899    0.000080    0.006297    0.024120    0.120267    0.650173
# 50%      0.399629    0.010000    0.055293    0.126447    0.236390    0.675642
# 75%      0.427017    0.014484    0.073456    0.149692    0.282617    0.711359
# max      0.626744    0.019912    0.092296    0.168780    0.323974    1.000000

# %%
# Spread of Results: Model Performance by Classifier used
g = sns.FacetGrid(results, col='model_type', palette="Set1")
g = (g.map(sns.kdeplot, 'auc-roc', shade=True, color='tab:red'))
sns.set(rc={'figure.figsize':(20,12)})

# %% [markdown]
# ### Performance spread of the model might be particularly useful for overall fitting process across classifier types

# %%
# Overview of Model Performance by AUC
sns.catplot(x="auc-roc", y="model_type", data=results)

# %% [markdown]
# # VII: Choosing best model
#
# ### Refernce guide for Imbalanced Classes: Potential Issues with Accuracy ROC
# - ROC curves should be used when there are roughly equal numbers of observations for each class.
# - Since ROC curves present an optimistic picture of the model on datasets with a class imbalance.
# - ROC curve with an imbalanced dataset might be deceptive and lead to incorrect interpretations of the model skill.
#
# ### Metric Selection: Partial Imbalance in the classes -> Metric used F1
# - Precision-Recall curves should be used when there is a moderate to large class imbalance.
# - e.g. a classifier that tells if a person is honest or not.
#
# #### Precision: measure of result relevancy/ how many selected items are relevant?
# - assume that you can misclassify a liar person as honest but not often
# - trying to identify liar from honest as a whole group
#   - Judicial System
#
# #### Recall: measure of how many truly relevant results are returned/ how relevant items are selected ?
# - Focus => coverage/outreach
# - really concerned if you think a liar person to be honest
# -  it's okay if you classified someone honest as a liar but your model should not claim a liar person as honest
# - focusing on a specific class and you are trying not to make a mistake about it.
#     - Disease patients  => find all patients who actually have the disease => care if non-infected is diseased or not!
#     - Website/Amazon: good chances to be a buyer => don't care about the guy that is not going to buy (so precision is not important)
#
# ### Precison vs Recall Note
# - Precison: Of all the schools that were predicted as recepients of donations, what fraction actually got the funding ?
# - Recall: Of all the schools that actually received the funding, what fraction was correctly predicted as recepient of donations ?
#
# - We care about the schools that did not receive donation within 60 days therefore Recall <> Precision
# - Precision

# %%
# Evaluation Metric
stats='r_at_50' # selected
# stats='f1_at_50'# stats='auc-roc'# stats='p_at_50' 

# Window
train_date=(('2012-01-01 00:00:00'), ('2012-12-30 00:00:00')) # 1 year
test_date=(('2012-12-31 00:00:00'), ('2013-06-29 00:00:00'))  # 6 months

# Extract the best model
best_fit, mod_stat = cl.best_model(model_data=df_m, model_results=results, time_var=time_var, tr_date=train_date, 
                              te_date=test_date, pred_var=pred_var, eval_stat=stats, window='best')
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# Class Skewness

# %%
best_fit
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ### Model Robustness over windows

# %%
# Robustness across windows
stats='r_at_50' # selected

# Robustness across windows I
# train_date=(('2012-01-01 00:00:00'), ('2012-12-30 00:00:00')) # 1 year
# test_date=(('2012-12-31 00:00:00'), ('2013-06-29 00:00:00'))  # 6 months
# Robustness across windows II
# train_date=(('2012-01-01 00:00:00'), ('2013-06-30 00:00:00')) # 1.5 years
# test_date=(('2013-07-01 00:00:00'), ('2013-12-31 00:00:00'))  # 6 months
# Robustness across windows III
train_date=(('2012-01-01 00:00:00'), ('2012-12-31 00:00:00')) # 2 years
test_date=(('2013-01-01 00:00:00'), ('2013-12-31 00:00:00'))  # 1year

# Extract the best model
by_pred_probs = cl.best_model(model_data=df_m, model_results=results, time_var=time_var, tr_date=train_date, 
                              te_date=test_date, pred_var=pred_var, eval_stat=stats)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# Class Skewness

# %% [markdown]
# ### Feature Importance

# %%
# Feature Importance {top 25 features}
feature_imp_all = pd.Series(best_fit.feature_importances_,index=bx_train.columns).sort_values(ascending=False)
feature_imp = feature_imp_all[0:25]

# Add labels 
plt.figure(figsize=(6,4))
sns.barplot(x=feature_imp, y=feature_imp.index)
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# # VIII Model Result & Summary
#
# ### Expanded in the note
# Average AUC-ROC score for all models was more than 60% which indicates that model(s) perform marginally better than a random guess. On an aggregate level it can be seen that Decision Tree (DT) had a wider range of accuracy from 60% onwards.  Further on selecting the best model based on optimal value of different metrics (auc-roc, f_at_50, r_at_50, p_at_50), a relatively common trend was observed, where the recall performed well and precision was low. Given the context of the current problem, it is imperative to identify the vulnerable projects and therefore recall (measure of how many truly relevant results are returned) is chosen over precision (measure of result relevancy)

# %% [markdown]
# ## Visualise Tree
#
#
# Reference: http://www.graphviz.org/pdf/dotguide.pdf

# %%
# Base Decision Tree with restrained depth
model = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=5, max_features='sqrt', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=10,
            min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=-1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
# Fit the classifier
model.fit(bx_train, by_train)

# Extract single tree
estimator = model.estimators_[3]

# Export as dot file
export_graphviz(estimator,out_file='charts/tree_cr.dot',
                feature_names=X_train.columns.tolist(),
                class_names=['Delinquent','Not Delinquent'],
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# Convert .dot to .png format for view
graphviz.render('dot', 'png', 'charts/tree_cr.dot')

# Plot Tree
graphviz.Source.from_file('charts/tree_cr.dot')
